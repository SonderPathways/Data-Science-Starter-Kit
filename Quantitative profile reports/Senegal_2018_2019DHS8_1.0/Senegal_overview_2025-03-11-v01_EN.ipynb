# %% [raw]
# title: General Overview
# author: Sonder Segmentation Science WS Team
# date: "{{ datetime.now().strftime('%Y-%m-%d') }}"
# output:
#     general:
#         input: false
#     html:
#         toc_depth: 5

# %% [markdown]
# # 🇸🇳 Senegal Segmentation Overview

# %% [markdown]
# ## 1. Basic setup
#
# Importing libraries, loading data, basic transformations, etc.

# %% [markdown]
# ### 1.1. Load libraries

# %%
# Load libraries
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import json

from plotly.subplots import make_subplots

# Configure Plotly renderer
# this enable chart in the exported HTML file
# https://github.com/microsoft/vscode-jupyter/issues/6999
pio.renderers.default = "notebook_connected"

# %%
# R Packages, libraries and utilities
import rpy2
import rpy2.robjects as ro
from rpy2.robjects import r, Formula, pandas2ri
from rpy2.robjects.packages import importr

# %%
# Check R version
r_version = ro.r('version')

# %%
pandas2ri.activate()
ro.r('library(survey)')
ro.r('library(base)')
ro.r('library(dplyr)')
# Out:
# R[write to console]: Cargando paquete requerido: grid
#
# R[write to console]: Cargando paquete requerido: Matrix
#
# R[write to console]: Cargando paquete requerido: survival
#
# R[write to console]:
# Adjuntando el paquete: ‘survey’
#
#
# R[write to console]: The following object is masked from ‘package:graphics’:
#
#     dotchart
#
#
# R[write to console]:
# Adjuntando el paquete: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### 1.2. Load data

# %%
# Load the RDS file
rds_path = 'Senegal/senegal.rds'
rds_path_urban = 'Senegal/urban.rds'
rds_path_rural = 'Senegal/rural.rds'
readRDS = ro.r['readRDS']
r_data = readRDS(rds_path)
r_data_urban = readRDS(rds_path_urban)
r_data_rural = readRDS(rds_path_rural)

# %%
# Convert the R data to a pandas DataFrame
df = pandas2ri.rpy2py(r_data)
df_urban = pandas2ri.rpy2py(r_data_urban)
df_rural = pandas2ri.rpy2py(r_data_rural)

# %%
# Display the DataFrame
print('rows x cols:', df.shape, 'loaded')
print('URBAN rows x cols:', df_urban.shape, 'loaded')
print('RURAL rows x cols:', df_rural.shape, 'loaded')
# Out:
# rows x cols: (7816, 306) loaded
# URBAN rows x cols: (2289, 306) loaded
# RURAL rows x cols: (5527, 306) loaded

# %% [markdown]
# ### 1.3. Some helpers

# %% [markdown]
# #### 1.3.1. Test of HTML Styles

# %% [markdown]
# <style>
#     .pill {
#         display: inline-block;
#         padding: 4px 8px;
#         font-size: 10px;
#         text-transform: uppercase;
#         border-radius: 3px;
#         margin-left: 4px;
#         color: white;
#         background-color: black;
#         height: 18px;
#         letter-spacing: 1px;
#     }
# </style>
# <p class="pill">test of text</p>

# %% [markdown]
# #### 1.3.2. Dictionary of colors

# %%
colors = {
    'Total': '#FFFFFF',  # White or transparent for root
    'Rural': '#7AC943',  # Blue for Rural category
    'Urban': '#7A8291',  # Green for Urban category
    # Rural segments
    'R2': '#14ABF7',
    'R3.1': '#8B7FEA',
    'R3.2': '#B5A4EA',
    'R4': '#F26185',
    # Urban segments
    'U1': '#21D6D6',
    'U2.1': '#14ABF7',
    'U2.2': '#76B5E5',
    'U3.1': '#8B7FEA',
    'U3.2': '#B5A4EA'
}

colors_yes_no = {'Yes': '#04859B', 'No': '#CCC'}

# %% [markdown]
# ### 1.5. Basic variables in the R runtime

# %%
# Renaming columns for better visualization
df.rename(columns={'class': 'Segment'}, inplace=True)
df_rural.rename(columns={'class': 'Segment'}, inplace=True)
df_urban.rename(columns={'class': 'Segment'}, inplace=True)

# %%
# Global variables required in the R runtime:
# ------------------------------------------

# Assign the R DataFrame to an R variable
ro.globalenv['senegal'] = df
ro.globalenv['urban'] = df_urban
ro.globalenv['rural'] = df_rural

ro.r('rural$Segment <- factor(rural$Segment)')
ro.r('urban$Segment <- factor(urban$Segment)')
ro.r('senegal$Segment <- factor(senegal$Segment)')

# Define the survey design in R
ro.r('rural.des <-svydesign(id=~v021, strata=~v023, weights=~wt, data=rural)')
ro.r('urban.des <-svydesign(id=~v021, strata=~v023, weights=~wt, data=urban)')
ro.r('senegal.des <-svydesign(id=~v021, strata=~v023, weights=~wt, data=senegal, nest=TRUE)')

# %% [markdown]
# ### 1.6. Main functions

# %% [markdown]
# #### 1.6.1. Table creation

# %%
# Function to create contingency tables by demand
def create_table(current_design, var_of_iterest, labels={}):
    # create contingency table
    ro.r('current_table <- as.data.frame(svytable(~Segment + ' + var_of_iterest + ', design = ' + current_design + '))')
    ro.r('current_table$Segment <- as.character(current_table$Segment)')
    inner_table = ro.r('current_table')
    with (ro.default_converter + pandas2ri.converter).context():
        inner_table = ro.conversion.get_conversion().rpy2py(inner_table)  
    
    # calculate percentage
    inner_total = inner_table.groupby('Segment', observed=False)['Freq'].transform('sum')
    inner_table['percentage'] = inner_table['Freq'] / inner_total * 100
    
    # replace binary for nice values
    inner_table[var_of_iterest] = inner_table[var_of_iterest].cat.rename_categories(labels)
          
    # remove frequencies to reduce confusion  
    # inner_table = inner_table.drop("Freq", axis=1)
    
    return inner_table

# %% [markdown]
# #### 1.6.2. Load Map

# %%
# Load your geojson data (replace with actual path)
geo_df = gpd.read_file('Senegal/gadm41_SEN_1.json')
print(type(geo_df))
print(geo_df.crs)
display(geo_df)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# EPSG:4326
#        GID_1 GID_0  COUNTRY       NAME_1              VARNAME_1 NL_NAME_1  \
# 0    SEN.1_1   SEN  Senegal        Dakar          CapVert|Dacar        NA
# 1    SEN.2_1   SEN  Senegal     Diourbel                     NA        NA
# 2    SEN.3_1   SEN  Senegal       Fatick                     NA        NA
# 3    SEN.4_1   SEN  Senegal     Kaffrine                     NA        NA
# 4    SEN.5_1   SEN  Senegal      Kaolack                     NA        NA
# 5    SEN.6_1   SEN  Senegal     Kédougou        SénégalOriental        NA
# 6    SEN.7_1   SEN  Senegal        Kolda                     NA        NA
# 7    SEN.8_1   SEN  Senegal        Louga                     NA        NA
# 8    SEN.9_1   SEN  Senegal        Matam                     NA        NA
# 9   SEN.10_1   SEN  Senegal  Saint-Louis  Fleuve|ValléeduFleuve        NA
# 10  SEN.11_1   SEN  Senegal      Sédhiou                     NA        NA
# 11  SEN.12_1   SEN  Senegal  Tambacounda        SénégalOriental        NA
# 12  SEN.13_1   SEN  Senegal        Thiès                     NA        NA
# 13  SEN.14_1   SEN  Senegal   Ziguinchor                     NA        NA
#
#     TYPE_1 ENGTYPE_1 CC_1 HASC_1  ISO_1  \
# 0   Région    Region    1  SN.DK  SN-DK
# 1   Région    Region    3  SN.DB  SN-DB
# 2   Région    Region    9  SN.FK  SN-FK
# 3   Région    Region   12  SN.KF  SN-KA
# 4   Région    Region    6  SN.KC  SN-KL
# 5   Région    Region   13  SN.KG     NA
# 6   Région    Region   10  SN.KD  SN-KD
# 7   Région    Region    8  SN.LG  SN-LG
# 8   Région    Region   11  SN.MT  SN-MT
# 9   Région    Region    4  SN.ST  SN-SL
# 10  Région    Region   14  SN.SD     NA
# 11  Région    Region    5  SN.TB  SN-TC
# 12  Région    Region    7  SN.TH     NA
# 13  Région    Region    2  SN.ZG  SN-ZG
#
#                                              geometry
# 0   MULTIPOLYGON (((-17.4676 14.6487, -17.4685 14....
# 1   MULTIPOLYGON (((-16.0433 14.555, -16.0687 14.5...
# 2   MULTIPOLYGON (((-16.6535 13.6474, -16.6482 13....
# 3   MULTIPOLYGON (((-15.3949 13.7573, -15.398 13.7...
# 4   MULTIPOLYGON (((-15.9989 13.5917, -16.1414 13....
# 5   MULTIPOLYGON (((-12.189 12.3609, -12.1907 12.3...
# 6   MULTIPOLYGON (((-14.8793 12.6791, -14.9756 12....
# 7   MULTIPOLYGON (((-14.8996 14.6906, -14.9095 14....
# 8   MULTIPOLYGON (((-12.8459 15.1994, -12.8384 15....
# 9   MULTIPOLYGON (((-13.9646 16.224, -13.9529 16.2...
# 10  MULTIPOLYGON (((-15.8337 12.4447, -15.8878 12....
# 11  MULTIPOLYGON (((-13.3064 12.6444, -13.31 12.64...
# 12  MULTIPOLYGON (((-16.8858 14.2476, -16.8971 14....
# 13  MULTIPOLYGON (((-16.4981 12.3534, -16.51 12.35...

# %% [markdown]
# #### 1.6.3. Bar chart creation

# %%
def create_bar_chart(current_data, var_of_interest, title):
    # Create the stacked bar chart with customizations
    fig = px.bar(current_data, 
                x='Segment', 
                y='percentage', 
                color=var_of_interest, 
                text='percentage', 
                labels={'percentage': 'Percentage', 'Segment': 'Segment'},
                title=title,
                barmode='stack',
                color_discrete_sequence=['#5778a4', '#e49444', '#d1615d', '#85b6b2', '#6a9f58', '#e7ca60', '#a87c9f', '#f1a2a9', '#967662', '#b8b0ac'],
                color_discrete_map=colors_yes_no
    )

    # Update the text format to show 2 decimal places and the "%" symbol
    fig.update_traces(texttemplate='%{text:.1f}%', textposition='auto', cliponaxis=False)

    # Increase the font size for text over the bars
    fig.update_traces(textfont_size=16)

    # Change the background of the plot area and the overall figure
    fig.update_layout(
        plot_bgcolor='#fcfcf7',  # transparent plot area background
        paper_bgcolor='#fcfcf7',  # light gray overall background
        margin=dict(t=100)  # Increase top margin to 100 (adjust as needed)
    )

    # Show the plot
    return fig

# %% [markdown]
# ## 2. General distribution

# %% [markdown]
# ### 2.1. Distribution of Segments

# %% [markdown]
# #### 2.1.1. Rural Segments
#
# R3.1-S is relatively smaller, while R3.2-S and R2-S together account for more than 70% of the rural population.

# %%
# RURAL Segments 
ro.r('table_dist_rural <- as.data.frame(svytable(~Segment, design = rural.des))')
ro.r('table_dist_rural$Segment <- as.character(table_dist_rural$Segment)')
table_dist_rural = ro.r('table_dist_rural')

# conversion
with (ro.default_converter + pandas2ri.converter).context():
        table_dist_rural = ro.conversion.get_conversion().rpy2py(table_dist_rural)  

# calculate percentage
current_total = table_dist_rural['Freq'].sum()
table_dist_rural['percentage'] = table_dist_rural['Freq'] / current_total * 100

display(table_dist_rural)
# Out:
#   Segment         Freq  percentage
# 1      R2  1684.274258   37.038789
# 2    R3.1   421.549434    9.270272
# 3    R3.2  1578.812145   34.719577
# 4      R4   862.689567   18.971362

# %% [markdown]
# #### 2.1.2. Urban Segments
#
# U3.2-S is quite small, only 3% of urban population, while U2.1-S and U1-S together account for more than 60% of urban population.

# %%
# URBAN Segments 
ro.r('table_dist_urban <- as.data.frame(svytable(~Segment, design = urban.des))')
ro.r('table_dist_urban$Segment <- as.character(table_dist_urban$Segment)')
table_dist_urban = ro.r('table_dist_urban')

# conversion
with (ro.default_converter + pandas2ri.converter).context():
        table_dist_urban = ro.conversion.get_conversion().rpy2py(table_dist_urban)  

# calculate percentage
current_total = table_dist_urban['Freq'].sum()
table_dist_urban['percentage'] = table_dist_urban['Freq'] / current_total * 100

display(table_dist_urban)
# Out:
#   Segment        Freq  percentage
# 1      U1  898.971723   31.191916
# 2    U2.1  963.277936   33.423170
# 3    U2.2  491.567448   17.056077
# 4    U3.1  428.776815   14.877410
# 5    U3.2   99.472430    3.451427

# %% [markdown]
# #### 2.1.3. National Distribution
#
# Rural takes up 62% and Urban takes up 38%. Overall, 4 out of the 9 segments are small (< 10% each)

# %%
# All Senegal Segments 
ro.r('table_dist_senegal <- as.data.frame(svytable(~Segment, design = senegal.des))')
ro.r('table_dist_senegal$Segment <- as.character(table_dist_senegal$Segment)')
table_dist_senegal = ro.r('table_dist_senegal')

# conversion
with (ro.default_converter + pandas2ri.converter).context():
        table_dist_senegal = ro.conversion.get_conversion().rpy2py(table_dist_senegal)  

# calculate percentage
current_total = table_dist_senegal['Freq'].sum()
table_dist_senegal['percentage'] = table_dist_senegal['Freq'] / current_total * 100
table_dist_senegal['Type'] = table_dist_senegal['Segment'].apply(lambda x: 'Rural' if x.startswith('R') else 'Urban')

display(table_dist_senegal)
# Out:
#   Segment         Freq  percentage   Type
# 1      R2  1684.274258   22.670419  Rural
# 2    R3.1   421.549434    5.674077  Rural
# 3    R3.2  1578.812145   21.250894  Rural
# 4      R4   862.689567   11.611847  Rural
# 5      U1   898.971723   12.100206  Urban
# 6    U2.1   963.277936   12.965771  Urban
# 7    U2.2   491.567448    6.616523  Urban
# 8    U3.1   428.776815    5.771358  Urban
# 9    U3.2    99.472430    1.338904  Urban

# %% [markdown]
# ##### 2.1.3.1. Prepare data for 2 level pie chart (sunburst)

# %%
def prepare_sunburst_data(df):
    # Create a copy to avoid modifying the original
    df_sunburst = df.copy()
    
    # Add a root node and type nodes
    root_and_types = pd.DataFrame({
        'Segment': ['Total', 'Rural', 'Urban'],
        'Type': ['', 'Total', 'Total'],  # Empty string for root, Total for Rural/Urban
        'percentage': [100, 
                      df[df['Type'] == 'Rural']['percentage'].sum(),
                      df[df['Type'] == 'Urban']['percentage'].sum()]
    })
    
    # Modify the Type column to point to Rural or Urban instead of Total
    df_sunburst['Type'] = df_sunburst['Type']
    
    # Combine the root and type rows with the data
    df_sunburst = pd.concat([root_and_types, df_sunburst], ignore_index=True)
    
    return df_sunburst

# Prepare the data
sunburst_data = prepare_sunburst_data(table_dist_senegal)

# %%
# Function to map colors based on the dictionary
def map_colors(df, color_dict):
    return [color_dict[segment] for segment in df['Segment']]

# Create a subplot with two charts (side by side)
fig = make_subplots(
    rows=1, cols=3,  # 1 row and 3 columns
    specs=[[{"type": "pie"}, {"type": "pie"}, {"type": "sunburst"}]],  # Specify type of chart
    subplot_titles=("Rural Distribution", "Urban Distribution", "National Distribution")  # Titles for the subplots
)

# Add the pie chart for table_dist_rural
fig.add_trace(
    go.Pie(
        labels=table_dist_rural['Segment'],
        values=table_dist_rural['percentage'],
        marker=dict(colors=map_colors(table_dist_rural, colors)),  # Apply custom colors
        direction='clockwise',  # Set rotation to clockwise
        sort=False,
        hovertemplate='<b>%{label}</b><br>' +
                      'Percentage: %{value:.2f}%<br>' +
                      '<extra></extra>'  # This removes the secondary box in the hover
    ),
    row=1, col=1  # First row, first column
)

# Add the pie chart for table_dist_urban
fig.add_trace(
    go.Pie(
        labels=table_dist_urban['Segment'],
        values=table_dist_urban['percentage'],
        marker=dict(colors=map_colors(table_dist_urban, colors)),  # Apply custom colors
        direction='clockwise',  # Set rotation to clockwise
        sort=False,
        hovertemplate='<b>%{label}</b><br>' +
                      'Percentage: %{value:.2f}%<br>' +
                      '<extra></extra>'  # This removes the secondary box in the hover
    ),
    row=1, col=2  # First row, second column
)

# Modified sunburst trace
fig.add_trace(
    go.Sunburst(
        ids=sunburst_data['Segment'],
        labels=sunburst_data['Segment'],
        parents=sunburst_data['Type'],
        values=sunburst_data['percentage'],
        marker=dict(colors=map_colors(sunburst_data, colors)),
        branchvalues='total',
        hovertemplate='<b>%{label}</b><br>' +
                      'Percentage: %{value:.2f}%<br>' +
                      '<extra></extra>'  # This removes the secondary box in the hover
    ),
    row=1, col=3
)

# Configure the layout and enforce the category order
fig.update_layout(
    title_text="Segment Distribution",  # Overall title
    title_x=0.5,  # Center the title
    annotations=[{"font": {"size": 14}}]  # Adjust the size of the subplot titles
)

# Show the chart
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6c5f554c-8162-4d69-b4f2-1116135e37c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c5f554c-8162-4d69-b4f2-1116135e37c1")) {                    Plotly.newPlot(                        "6c5f554c-8162-4d69-b4f2-1116135e37c1",                        [{"direction":"clockwise","hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003ePercentage: %{value:.2f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","labels":["R2","R3.1","R3.2","R4"],"marker":{"colors":["#14ABF7","#8B7FEA","#B5A4EA","#F26185"]},"sort":false,"values":[37.038788922350875,9.270272007127266,34.71957699818918,18.971362072332663],"type":"pie","domain":{"x":[0.0,0.2888888888888889],"y":[0.0,1.0]}},{"direction":"clockwise","hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003ePercentage: %{value:.2f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","labels":["U1","U2.1","U2.2","U3.1","U3.2"],"marker":{"colors":["#21D6D6","#14ABF7","#76B5E5","#8B7FEA","#B5A4EA"]},"sort":false,"values":[31.191916257450526,33.423169988141886,17.05607671589096,14.87740956076368,3.4514274777529503],"type":"pie","domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,1.0]}},{"branchvalues":"total","hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003ePercentage: %{value:.2f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","ids":["Total","Rural","Urban","R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"labels":["Total","Rural","Urban","R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"marker":{"colors":["#FFFFFF","#7AC943","#7A8291","#14ABF7","#8B7FEA","#B5A4EA","#F26185","#21D6D6","#14ABF7","#76B5E5","#8B7FEA","#B5A4EA"]},"parents":["","Total","Total","Rural","Rural","Rural","Rural","Urban","Urban","Urban","Urban","Urban"],"values":[100.0,61.20723678795862,38.792763212041386,22.67041923909549,5.67407733829023,21.25089370505927,11.611846505513629,12.100206215051022,12.96577119145796,6.616523453659704,5.77135826299266,1.338904088880034],"type":"sunburst","domain":{"x":[0.7111111111111111,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{ ...

# %% [markdown]
# ### 2.2. Geographic Distribution

# %% [markdown]
# #### 2.2.1. Rural Segments

# %%
table_geo_dist_rural = create_table("rural.des", "v024")

# we need to get state names from the map
#----------------------------------------

# Rename the column 'v024' to 'State'
table_geo_dist_rural.rename(columns={'v024': 'State'}, inplace=True)

# Ensure the ID column in both DataFrames is of the same type
table_geo_dist_rural['State'] = table_geo_dist_rural['State'].astype(int)
geo_df['CC_1'] = geo_df['CC_1'].astype(int)

# Perform the merge to bring the state names into table_geo_dist_rural
merged_df = table_geo_dist_rural.merge(geo_df[['CC_1', 'NAME_1']], 
                                       left_on='State', right_on='CC_1', 
                                       how='left')

# Replace the 'State' column with the state names
merged_df['State'] = merged_df['NAME_1']

# Drop the extra columns used for merging if no longer needed
merged_df.drop(['CC_1', 'NAME_1'], axis=1, inplace=True)

# The updated DataFrame
table_geo_dist_rural = merged_df

# calculate percentage
inner_total = table_geo_dist_rural.groupby('State')['Freq'].transform('sum')
table_geo_dist_rural['percentage_state'] = table_geo_dist_rural['Freq'] / inner_total * 100

# Verify the state column
display(table_geo_dist_rural)
# Out:
#    Segment        State        Freq  percentage  percentage_state
# 0       R2        Dakar   89.154514    5.293349         94.830080
# 1     R3.1        Dakar    0.440912    0.104593          0.468980
# 2     R3.2        Dakar    4.419589    0.279931          4.700940
# 3       R4        Dakar    0.000000    0.000000          0.000000
# 4       R2   Ziguinchor    5.600681    0.332528          5.390304
# 5     R3.1   Ziguinchor   84.403481   20.022202         81.233053
# 6     R3.2   Ziguinchor    1.168388    0.074004          1.124500
# 7       R4   Ziguinchor   12.730329    1.475656         12.252143
# 8       R2     Diourbel  489.800988   29.080833         55.018455
# 9     R3.1     Diourbel    0.000000    0.000000          0.000000
# 10    R3.2     Diourbel  385.922024   24.443822         43.349920
# 11      R4     Diourbel   14.525520    1.683748          1.631625
# 12      R2  Saint-Louis  125.347678    7.442237         39.279182
# 13    R3.1  Saint-Louis   11.170309    2.649822          3.500349
# 14    R3.2  Saint-Louis   65.660368    4.158846         20.575455
# 15      R4  Saint-Louis  116.941525   13.555458         36.645014
# 16      R2  Tambacounda   14.670562    0.871032          5.738163
# 17    R3.1  Tambacounda   84.048918   19.938093         32.874429
# 18    R3.2  Tambacounda    4.234288    0.268195          1.656176
# 19      R4  Tambacounda  152.712779   17.701939         59.731232
# 20      R2      Kaolack  177.603487   10.544808         37.726388
# 21    R3.1      Kaolack    0.000000    0.000000          0.000000
# 22    R3.2      Kaolack  280.336238   17.756149         59.548795
# 23      R4      Kaolack   12.827545    1.486925          2.724817
# 24      R2        Thiès  313.667996   18.623333         61.918393
# 25    R3.1        Thiès    0.000000    0.000000          0.000000
# 26    R3.2        Thiès  186.948963   11.841115         36.903922
# 27      R4        Thiès    5.965948    0.691552          1.177684
# 28      R2        Louga  200.414874   11.899183         48.997943
# 29    R3.1        Louga    0.730529    0.173296          0.178602
# 30    R3.2        Louga  114.253274    7.236660         27.932934
# 31      R4        Louga   93.628442   10.853086         22.890522
# 32      R2       Fatick  116.529969    6.918705         32.647909
# 33    R3.1       Fatick    0.000000    0.000000          0.000000
# 34    R3.2       Fatick  233.892537   14.814463         65.529085
# 35      R4       Fatick    6.506844    0.754251          1.823006
# 36      R2        Kolda    0.000000    0.000000          0.000000
# 37    R3.1        Kolda   89.581759   21.250594         31.545482
# 38    R3.2        Kolda    0.000000    0.000000          0.000000
# 39      R4        Kolda  194.394750   22.533569         68.454518
# 40      R2        Matam   84.713730    5.029687         39.823115
# 41    R3.1        Matam   15.617120    3.704695          7.341459
# 42    R3.2        Matam   16.577543    1.050001          7.792945
# 43      R4        Matam   95.816629   11.106733         45.042482
# 44      R2     Kaffrine   61.858506    3.672710         15.659890
# 45    R3.1     Kaffrine    0.000000    0.000000          0.000000
# 46    R3.2     Kaffrine  282.317927   17.881667         71.470653
# 47      R4     Kaffrine   50.835949    5.892728         12.869457
# 48      R2     Kédougou    1.420813    0.084358          2.308679
# 49    R3.1     Kédougou   29.845796    7.080023         48.496428
# 50    R3.2     Kédougou    0.000000    0.000000          0.000000
# 51      R4     Kédougou   30.275647    3.509449         49.194893
# 52      R2      Sédhiou    3.490460    0.207238          1.858509
# 53    R3.1      Sédhiou  105.710610   25.076682         56.286012
# 54    R3.2      Sédhiou    3.081006    0.195147          1.640493
# 55      R4      Sédhiou   75.527660    8.754906         40.214987

# %% [markdown]
# #### 2.2.2. Urban Segments

# %%
table_geo_dist_urban = create_table("urban.des", "v024")

# we need to get state names from the map
#----------------------------------------

# Rename the column 'v024' to 'State'
table_geo_dist_urban.rename(columns={'v024': 'State'}, inplace=True)

# Ensure the ID column in both DataFrames is of the same type
table_geo_dist_urban['State'] = table_geo_dist_urban['State'].astype(int)
geo_df['CC_1'] = geo_df['CC_1'].astype(int)

# Perform the merge to bring the state names into table_geo_dist_urban
merged_df = table_geo_dist_urban.merge(geo_df[['CC_1', 'NAME_1']], 
                                       left_on='State', right_on='CC_1', 
                                       how='left')

# Replace the 'State' column with the state names
merged_df['State'] = merged_df['NAME_1']

# Drop the extra columns used for merging if no longer needed
merged_df.drop(['CC_1', 'NAME_1'], axis=1, inplace=True)

# The updated DataFrame
table_geo_dist_urban = merged_df

# calculate percentage
inner_total = table_geo_dist_urban.groupby('State')['Freq'].transform('sum')
table_geo_dist_urban['percentage_state'] = table_geo_dist_urban['Freq'] / inner_total * 100

# Verify the state column
display(table_geo_dist_urban)
# Out:
#    Segment    State        Freq  percentage  percentage_state
# 0       U1    Dakar  548.791639   61.046596         37.783765
# 1     U2.1    Dakar  572.603015   59.443178         39.423154
# 2     U2.2    Dakar  162.471889   33.051800         11.186030
# 3     U3.1    Dakar  113.689097   26.514749          7.827383
# 4     U3.2    Dakar   54.897934   55.189095          3.779669
# ..     ...      ...         ...         ...               ...
# 65      U1  Sédhiou    2.804528    0.311971          8.052693
# 66    U2.1  Sédhiou    1.255392    0.130325          3.604630
# 67    U2.2  Sédhiou   14.060892    2.860420         40.373298
# 68    U3.1  Sédhiou   16.408253    3.826758         47.113319
# 69    U3.2  Sédhiou    0.298142    0.299723          0.856061
#
# [70 rows x 5 columns]

# %%
# IMPORTANT note about geographic composition: 
# --------------------------------------------

# The column "percentage" stores how R2 is distributed 
# across all the states, Not the composition of a specific State. 
# The composition of each state is stored in "percentage_state"

# Filtering rows with Segment = R2, and sum the percentage
total_percentage_R2 = table_geo_dist_rural.loc[table_geo_dist_rural['Segment'] == 'R2', 'percentage'].sum()

# Filtering rows with State = Dakar, and sum the percentage_state
total_percentage_Dakar = table_geo_dist_rural.loc[table_geo_dist_rural['State'] == 'Dakar', 'percentage_state'].sum()

# Check the values
print("Some Tests:")
print(f"Total percentage of R2 across states: {total_percentage_R2}")
print(f"Total composition of Dakar: {total_percentage_Dakar}")
# Out:
# Some Tests:
# Total percentage of R2 across states: 100.0
# Total composition of Dakar: 100.00000000000001

# %%
# Map with pie charts over each state
# -----------------------------------

# Create the subplots
fig = make_subplots(
    rows=1, cols=2,  # 1 row and 2 columns
    subplot_titles=("Urban Distribution by State", "Rural Distribution by State")  # Titles for the plots
)

# Create a set to track segments already added to the legend
legend_segments = set()

# Urban chart (left side)
for segment in table_geo_dist_urban['Segment'].unique():
    segment_data = table_geo_dist_urban[table_geo_dist_urban['Segment'] == segment]
    fig.add_trace(
        go.Bar(
            x=segment_data['State'],
            y=segment_data['percentage_state'],
            name=segment,  # Segment name for the legend
            legendgroup=segment,  # Same legend group for urban and rural
            showlegend=(segment not in legend_segments),  # Show legend only if not already added
            marker=dict(color=colors.get(segment, "#CCCCCC")),  # Use custom color or default to gray
            text=[f'{x:.1f}%' for x in segment_data['percentage_state']],  
            textposition='inside',  
            hovertemplate='<b>%{x}</b><br>' +
                         'Segment: ' + segment + '<br>' +
                         'Percentage: %{y:.1f}%<br>' +
                         '<extra></extra>'  # This removes the secondary box in the hover
        ),
        row=1, col=1  # Left chart
    )
    legend_segments.add(segment)  # Mark the segment as added

# Rural chart (right side)
for segment in table_geo_dist_rural['Segment'].unique():
    segment_data = table_geo_dist_rural[table_geo_dist_rural['Segment'] == segment]
    fig.add_trace(
        go.Bar(
            x=segment_data['State'],
            y=segment_data['percentage_state'],
            name=segment,  # Segment name for the legend
            legendgroup=segment,  # Same legend group for urban and rural
            showlegend=(segment not in legend_segments),  # Show legend only if not already added
            marker=dict(color=colors.get(segment, "#CCCCCC")),  # Use custom color or default to gray
            text=[f'{x:.1f}%' for x in segment_data['percentage_state']],  
            textposition='inside',  
            hovertemplate='<b>%{x}</b><br>' +
                         'Segment: ' + segment + '<br>' +
                         'Percentage: %{y:.1f}%<br>' +
                         '<extra></extra>'  # This removes the secondary box in the hover
        ),
        row=1, col=2  # Right chart
    )
    legend_segments.add(segment)  # Mark the segment as added

# Configure the layout
fig.update_layout(
    title="Segment Distribution by State (Urban vs Rural)",
    barmode='stack',  # Stack the bars
    title_x=0.5,  # Center the title
    xaxis_title="State",
    yaxis_title="Percentage",
    legend_title="Segment",
)

# Display the charts
fig.show()
# Out:
# <div>                            <div id="fea65ccc-2495-48d0-bccb-9a9ce5b8e744" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fea65ccc-2495-48d0-bccb-9a9ce5b8e744")) {                    Plotly.newPlot(                        "fea65ccc-2495-48d0-bccb-9a9ce5b8e744",                        [{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eSegment: U1\u003cbr\u003ePercentage: %{y:.1f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","marker":{"color":"#21D6D6"},"name":"U1","showlegend":true,"text":["37.8%","17.1%","20.1%","25.1%","11.2%","25.0%","35.8%","32.3%","27.3%","13.5%","6.5%","7.7%","14.4%","8.1%"],"textposition":"inside","x":["Dakar","Ziguinchor","Diourbel","Saint-Louis","Tambacounda","Kaolack","Thi\u00e8s","Louga","Fatick","Kolda","Matam","Kaffrine","K\u00e9dougou","S\u00e9dhiou"],"y":[37.783764577662154,17.13714139835873,20.121368930379717,25.09231349780361,11.244206730535506,24.9712440577892,35.80623419205438,32.25872428500728,27.26583019343838,13.526441124526118,6.465151822369794,7.695689415761166,14.441141929929627,8.052692827191112],"type":"bar","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eSegment: U2.1\u003cbr\u003ePercentage: %{y:.1f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","marker":{"color":"#14ABF7"},"name":"U2.1","showlegend":true,"text":["39.4%","8.9%","27.6%","34.4%","18.9%","28.3%","36.4%","37.3%","20.4%","4.6%","28.6%","19.1%","10.0%","3.6%"],"textposition":"inside","x":["Dakar","Ziguinchor","Diourbel","Saint-Louis","Tambacounda","Kaolack","Thi\u00e8s","Louga","Fatick","Kolda","Matam","Kaffrine","K\u00e9dougou","S\u00e9dhiou"],"y":[39.423154395432654,8.889676029430756,27.61005720022567,34.39029374864338,18.89729396347394,28.275162212658735,36.36341352142558,37.30234469999393,20.434789972681035,4.594158970072542,28.551320926843935,19.117679763163157,9.950379623502878,3.6046301387303337],"type":"bar","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eSegment: U2.2\u003cbr\u003ePercentage: %{y:.1f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","marker":{"color":"#76B5E5"},"name":"U2.2","showlegend":true,"text":["11.2%","37.4%","29.5%","21.2%","22.8%","22.2%","13.6%","17.2%","24.0%","34.4%","22.7%","41.7%","40.8%","40.4%"],"textposition":"inside","x":["Dakar","Ziguinchor","Diourbel","Saint-Louis","Tambacounda","Kaolack","Thi\u00e8s","Louga","Fatick","Kolda","Matam","Kaffrine","K\u00e9dougou","S\u00e9dhiou"],"y":[11.186029757395897,37.38239613523477,29.547023240431187,21.196761427092717,22.752079381091825,22.20040066864131,13.60500274470928,17.233591013648812,24.03202992850465,34.367965931557386,22.72934843745266,41.71980674854091,40.79086555665349,40.37329780708513],"type":"bar","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003cb\u003e%{x}\u003c\u002fb\u003e\u003cbr\u003eSegment: U3.1\u003cbr\u003ePercentage: %{y:.1f}%\u003cbr\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","marker":{"color":"#8B7FEA"},"name":"U3.1","showlegend":true,"text":["7.8%","34.4%","20.3%","15.9%","46.5%","19.9%","10.0%","12.6%","24.7%","44.3%","40.5%","28.9%","33.3%","47.1%"],"textposition":"inside","x":["Dakar","Ziguinchor","Diourbel","Saint-Louis","Tambacounda","Kaolack","Thi\u00e8s","Louga","Fatick","Kolda","Matam","Kaffrine","K\u00e9dougou","S\u00e9dhiou"],"y":[7.827382508819531,34.404134906168174,20.306771780970273,15.874541486700425,46.479279327651064,19.91392474072251,9.997868236370426,12.567193226729891,24.667058221547407,44.27177883921766,40.48638898369747,28.866037379414855,33.32457568844296,47.11331861897509],"type":"bar","xaxis":"x","yaxis":"y"},{"hovertemplate":"\u003 ...

# %% [markdown]
# Map with the distribution of each Segment

# %%
# Create the base map with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(24, 12))  # Two maps side by side

# Plot the base map
geo_df.plot(ax=axes[0], color='#DDD', edgecolor='#595959', linewidth=0.5)
axes[0].set_title('Distribution of Urban Segments', fontsize=16)

def plot_pie_for_state(state, x, y, current_table, colors, ax):
    inner_current_table = current_table[current_table['State'] == state]
    
    # Ensure we plot only if there's valid data for this state
    if not inner_current_table.empty:
        sizes = inner_current_table['percentage']
        classes = inner_current_table['Segment']  # Get class names for each segment
        
         # Map each class to its corresponding color using the dictionary
        cls = [colors.get(cl, '#CCCCCC') for cl in classes]  # Default to gray if class not in dict
        ax.pie(sizes, center=(x, y), radius=0.225, colors=cls, wedgeprops=dict(edgecolor='#595959', linewidth=0.5))

# Plot pie charts for urban data
for idx, row in geo_df.iterrows():
    state = row['NAME_1']  # Adjust based on your GeoJSON structure
    centroid = row.geometry.centroid
    plot_pie_for_state(state, centroid.x, centroid.y, table_geo_dist_urban, colors, axes[0])
    # Add state name as a label near the centroid
    axes[0].text(centroid.x, centroid.y + 0.3, state, fontsize=12, ha='center', va='center', color='#484848')

# Plot the second map with rural data
geo_df.plot(ax=axes[1], color='#DDD', edgecolor='#595959', linewidth=0.5)
axes[1].set_title('Distribution of Rural Segments', fontsize=16)

# Plot pie charts for rural data
for idx, row in geo_df.iterrows():
    state = row['NAME_1']  # Adjust based on your GeoJSON structure
    centroid = row.geometry.centroid
    plot_pie_for_state(state, centroid.x, centroid.y, table_geo_dist_rural, colors, axes[1])
    # Add state name as a label near the centroid
    axes[1].text(centroid.x, centroid.y + 0.3, state, fontsize=12, ha='center', va='center', color='#484848')

# Add a legend for the pie chart colors excluding Total, Rural, and Urban
excluded_segments = {"Total", "Rural", "Urban"}
legend_handles = [
    mpatches.Patch(color=color, label=segment)
    for segment, color in sorted(colors.items()) if segment not in excluded_segments
]
fig.legend(handles=legend_handles, loc='lower center', ncol=9, fontsize=14, frameon=False, title="Segments")

# Set map limits and hide axes
for ax in axes:
    ax.set_xlim(geo_df.total_bounds[0], geo_df.total_bounds[2])
    ax.set_ylim(geo_df.total_bounds[1], geo_df.total_bounds[3])
    ax.axis('off')

# Adjust layout for a cleaner appearance
plt.subplots_adjust(left=0.05, right=0.95, top=0.95, bottom=0.05, wspace=0.1)  # Adjust spacing between subplots

# Show the maps
plt.show()

# %% [markdown]
# ### 2.3. Age Distribution

# %%
# Quantile stats for Age
# Calculate the median age by segment (class) using the survey package
# Calculate the first and third quartiles
r_code = """
median_age <- svyby(~v012, ~Segment, senegal.des, svyquantile, quantiles = c(0.5), na.rm = TRUE)
median_age <- median_age %>% rename(median_age = v012)
q1_age <- svyby(~v012, ~Segment, senegal.des, svyquantile, quantiles = c(0.25), na.rm = TRUE)
q1_age <- q1_age %>%  rename(q1 = v012)
q3_age <- svyby(~v012, ~Segment, senegal.des, svyquantile, quantiles = c(0.75), na.rm = TRUE)
q3_age <- q3_age %>%  rename(q3 = v012)
min_age <- svyby(~v012, ~Segment, senegal.des, svyquantile, quantiles = c(0.0), na.rm = TRUE)
min_age <- min_age %>% rename(min = v012)
max_age <- svyby(~v012, ~Segment, senegal.des, svyquantile, quantiles = c(1.0), na.rm = TRUE)
max_age <- max_age %>% rename(max = v012)

age_stats <- full_join(q1_age, q3_age, by = "Segment")
age_stats <- full_join(age_stats, median_age, by = "Segment")
age_stats <- full_join(age_stats, min_age, by = "Segment")
age_stats <- full_join(age_stats, max_age, by = "Segment")

age_stats <- age_stats %>% 
  select("Segment", "min", "q1", "median_age", "q3", "max")
"""

ro.r(r_code)
table_age_stats = ro.r('age_stats')

# conversion
with (ro.default_converter + pandas2ri.converter).context():
        table_age_stats = ro.conversion.get_conversion().rpy2py(table_age_stats) 

display(table_age_stats)
# Out:
#   Segment   min    q1  median_age    q3   max
# 1      R2  16.0  25.0        31.0  37.0  49.0
# 2    R3.1  15.0  24.0        29.0  36.0  49.0
# 3    R3.2  16.0  25.0        31.0  38.0  49.0
# 4      R4  16.0  24.0        30.0  37.0  49.0
# 5      U1  19.0  29.0        35.0  40.0  49.0
# 6    U2.1  16.0  26.0        30.0  35.0  49.0
# 7    U2.2  18.0  30.0        36.0  44.0  49.0
# 8    U3.1  16.0  24.0        30.0  36.0  49.0
# 9    U3.2  22.0  38.0        43.0  46.0  49.0

# %%
# Melt the DataFrame to long format
melted_data = table_age_stats.melt(
    id_vars=["Segment"],
    value_vars=["min", "q1", "median_age", "q3", "max"],
    var_name="Statistic",
    value_name="Age"
)

# Create the boxplot
fig = px.box(
    table_age_stats,
    x="Segment",
    y=["min", "q1", "median_age", "q3", "max"],
    title="Age Statistics by Segment",
    points=False,  # This hides individual points. "all" to show them
    color="Segment",
    color_discrete_map=colors  # Use custom colors
)

# Update layout for better visualization
fig.update_layout(
    xaxis_title="Segment",
    yaxis_title="Age",
    title_x=0.5,  # Center the title
    showlegend=True
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="532be8be-1ec1-4a7e-ac13-059d4e2fd6d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("532be8be-1ec1-4a7e-ac13-059d4e2fd6d8")) {                    Plotly.newPlot(                        "532be8be-1ec1-4a7e-ac13-059d4e2fd6d8",                        [{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","marker":{"color":"#14ABF7"},"name":"R2","notched":false,"offsetgroup":"R2","orientation":"v","showlegend":true,"x":["R2","R2","R2","R2","R2"],"x0":" ","xaxis":"x","y":[16.0,25.0,31.0,37.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","marker":{"color":"#8B7FEA"},"name":"R3.1","notched":false,"offsetgroup":"R3.1","orientation":"v","showlegend":true,"x":["R3.1","R3.1","R3.1","R3.1","R3.1"],"x0":" ","xaxis":"x","y":[15.0,24.0,29.0,36.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","marker":{"color":"#B5A4EA"},"name":"R3.2","notched":false,"offsetgroup":"R3.2","orientation":"v","showlegend":true,"x":["R3.2","R3.2","R3.2","R3.2","R3.2"],"x0":" ","xaxis":"x","y":[16.0,25.0,31.0,38.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","marker":{"color":"#F26185"},"name":"R4","notched":false,"offsetgroup":"R4","orientation":"v","showlegend":true,"x":["R4","R4","R4","R4","R4"],"x0":" ","xaxis":"x","y":[16.0,24.0,30.0,37.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","marker":{"color":"#21D6D6"},"name":"U1","notched":false,"offsetgroup":"U1","orientation":"v","showlegend":true,"x":["U1","U1","U1","U1","U1"],"x0":" ","xaxis":"x","y":[19.0,29.0,35.0,40.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","marker":{"color":"#14ABF7"},"name":"U2.1","notched":false,"offsetgroup":"U2.1","orientation":"v","showlegend":true,"x":["U2.1","U2.1","U2.1","U2.1","U2.1"],"x0":" ","xaxis":"x","y":[16.0,26.0,30.0,35.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","marker":{"color":"#76B5E5"},"name":"U2.2","notched":false,"offsetgroup":"U2.2","orientation":"v","showlegend":true,"x":["U2.2","U2.2","U2.2","U2.2","U2.2"],"x0":" ","xaxis":"x","y":[18.0,30.0,36.0,44.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","marker":{"color":"#8B7FEA"},"name":"U3.1","notched":false,"offsetgroup":"U3.1","orientation":"v","showlegend":true,"x":["U3.1","U3.1","U3.1","U3.1","U3.1"],"x0":" ","xaxis":"x","y":[16.0,24.0,30.0,36.0,49.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":false,"hovertemplate":"Segment=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.2","marker":{"color":"#B5A4EA"},"name":"U3.2","notched":false,"offsetgroup":"U3.2","orientation":"v","showlegend":true,"x":["U3.2","U3.2" ...

# %%
r_code = """
# Create age groups
senegal <- senegal %>% 
  mutate(age.adj = case_when(
    v012 < 20 ~ "15-19",
    (v012 > 19 & v012 < 25) ~ "20-24",
    (v012 > 24 & v012 < 30) ~ "25-29",
    (v012 > 29 & v012 < 35) ~ "30-34",
    TRUE ~ "35-49"))

# update the survey design object, so it includes age.adj
senegal.des <-svydesign(id=~v021, strata=~v023, weights=~wt, data=senegal, nest=TRUE)

# Create the contingency table
table_age_groups <- svytable(~Segment + age.adj, design = senegal.des)
table_age_groups <- as.data.frame(table_age_groups)
"""

ro.r(r_code)
table_age_groups = ro.r('table_age_groups')

# conversion
with (ro.default_converter + pandas2ri.converter).context():
        table_age_groups = ro.conversion.get_conversion().rpy2py(table_age_groups)

# calculate percentage
current_total = table_age_groups.groupby('Segment', observed=False)['Freq'].transform('sum')
table_age_groups['percentage'] = table_age_groups['Freq'] / current_total * 100

display(table_age_groups)
# Out:
#    Segment age.adj        Freq  percentage
# 1       R2   15-19   59.122424    3.510261
# 2     R3.1   15-19   25.322092    6.006909
# 3     R3.2   15-19   81.571694    5.166650
# 4       R4   15-19   71.853726    8.329036
# 5       U1   15-19    1.016170    0.113037
# 6     U2.1   15-19   22.274264    2.312340
# 7     U2.2   15-19    3.176907    0.646281
# 8     U3.1   15-19   25.765391    6.009045
# 9     U3.2   15-19    0.000000    0.000000
# 10      R2   20-24  278.918534   16.560161
# 11    R3.1   20-24   90.190896   21.395094
# 12    R3.2   20-24  262.972559   16.656355
# 13      R4   20-24  146.080950   16.933200
# 14      U1   20-24   64.591732    7.185068
# 15    U2.1   20-24  159.211057   16.528050
# 16    U2.2   20-24   30.020068    6.107009
# 17    U3.1   20-24   86.199493   20.103581
# 18    U3.2   20-24    2.523859    2.537245
# 19      R2   25-29  376.101449   22.330179
# 20    R3.1   25-29  104.947857   24.895741
# 21    R3.2   25-29  318.760676   20.189905
# 22      R4   25-29  206.226145   23.905024
# 23      U1   25-29  170.065742   18.917808
# 24    U2.1   25-29  299.804284   31.123342
# 25    U2.2   25-29   69.536670   14.145906
# 26    U3.1   25-29  101.843723   23.752153
# 27    U3.2   25-29    1.698000    1.707006
# 28      R2   30-34  368.677243   21.889383
# 29    R3.1   30-34   77.163550   18.304745
# 30    R3.2   30-34  292.655018   18.536405
# 31      R4   30-34  147.066190   17.047406
# 32      U1   30-34  183.124058   20.370391
# 33    U2.1   30-34  210.443783   21.846632
# 34    U2.2   30-34  104.075770   21.172226
# 35    U3.1   30-34   73.118317   17.052768
# 36    U3.2   30-34   18.065335   18.161148
# 37      R2   35-49  601.454608   35.710016
# 38    R3.1   35-49  123.925039   29.397510
# 39    R3.2   35-49  622.852198   39.450684
# 40      R4   35-49  291.462556   33.785335
# 41      U1   35-49  480.174021   53.413696
# 42    U2.1   35-49  271.544548   28.189636
# 43    U2.2   35-49  284.758033   57.928578
# 44    U3.1   35-49  141.849891   33.082454
# 45    U3.2   35-49   77.185236   77.594602

# %%
# Create the stacked bar chart
fig = px.bar(
    table_age_groups,
    x="Segment",  # Segments on the X-axis
    y="percentage",  # Percentages on the Y-axis
    color="age.adj",  # Age groups as the stack categories
    title="Age Group Distribution by Segment",
    labels={"percentage": "Percentage", "age.adj": "Age Group"},
    color_discrete_sequence=px.colors.qualitative.T10  # Use Plotly's T10 color sequence
)

# Add percentage annotations to each bar section
fig.update_traces(
    texttemplate='%{y:.2f}%',  # Format the text as percentage with 2 decimals
    textposition='inside',  # Position the text inside the bar sections
    hovertemplate='Age Group: %{customdata}<br>Segment: %{x}<br>Percentage: %{y:.2f}%'  # Update hover tooltip
)

# Add custom data to include age group in hovertemplate
fig.for_each_trace(lambda trace: trace.update(customdata=table_age_groups[table_age_groups["age.adj"] == trace.name]["age.adj"].tolist()))

# Update layout for better visualization
fig.update_layout(
    xaxis_title="Segment",
    yaxis_title="Percentage",
    title_x=0.5,  # Center the title
    barmode="stack",  # Stack the bars
    showlegend=True
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="b95a03b1-0ac0-4927-ac0d-9dd60f65b1b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b95a03b1-0ac0-4927-ac0d-9dd60f65b1b2")) {                    Plotly.newPlot(                        "b95a03b1-0ac0-4927-ac0d-9dd60f65b1b2",                        [{"alignmentgroup":"True","hovertemplate":"Age Group: %{customdata}\u003cbr\u003eSegment: %{x}\u003cbr\u003ePercentage: %{y:.2f}%","legendgroup":"15-19","marker":{"color":"#4C78A8","pattern":{"shape":""}},"name":"15-19","offsetgroup":"15-19","orientation":"v","showlegend":true,"textposition":"inside","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[3.510261094306884,6.006909263220598,5.1666497663026325,8.329036161857282,0.11303692585667685,2.3123403088098966,0.6462809962143788,6.009044822071365,0.0],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}%","customdata":["15-19","15-19","15-19","15-19","15-19","15-19","15-19","15-19","15-19"]},{"alignmentgroup":"True","hovertemplate":"Age Group: %{customdata}\u003cbr\u003eSegment: %{x}\u003cbr\u003ePercentage: %{y:.2f}%","legendgroup":"20-24","marker":{"color":"#F58518","pattern":{"shape":""}},"name":"20-24","offsetgroup":"20-24","orientation":"v","showlegend":true,"textposition":"inside","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[16.560161308360964,21.39509360603245,16.65635521191157,16.9332000279076,7.18506826715839,16.528049802648027,6.107008940917501,20.10358069383952,2.5372447420858224],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}%","customdata":["20-24","20-24","20-24","20-24","20-24","20-24","20-24","20-24","20-24"]},{"alignmentgroup":"True","hovertemplate":"Age Group: %{customdata}\u003cbr\u003eSegment: %{x}\u003cbr\u003ePercentage: %{y:.2f}%","legendgroup":"25-29","marker":{"color":"#E45756","pattern":{"shape":""}},"name":"25-29","offsetgroup":"25-29","orientation":"v","showlegend":true,"textposition":"inside","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[22.33017854506684,24.89574140906095,20.18990524043634,23.905023647979284,18.917807718408078,31.12334174754729,14.145906178881068,23.752152503861485,1.7070056497061548],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}%","customdata":["25-29","25-29","25-29","25-29","25-29","25-29","25-29","25-29","25-29"]},{"alignmentgroup":"True","hovertemplate":"Age Group: %{customdata}\u003cbr\u003eSegment: %{x}\u003cbr\u003ePercentage: %{y:.2f}%","legendgroup":"30-34","marker":{"color":"#72B7B2","pattern":{"shape":""}},"name":"30-34","offsetgroup":"30-34","orientation":"v","showlegend":true,"textposition":"inside","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[21.88938299382355,18.304745250826258,18.53640529222053,17.04740565153955,20.370391338771867,21.84663170775668,21.172225789857393,17.05276834989319,18.16114776727582],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}%","customdata":["30-34","30-34","30-34","30-34","30-34","30-34","30-34","30-34","30-34"]},{"alignmentgroup":"True","hovertemplate":"Age Group: %{customdata}\u003cbr\u003eSegment: %{x}\u003cbr\u003ePercentage: %{y:.2f}%","legendgroup":"35-49","marker":{"color":"#54A24B","pattern":{"shape":""}},"name":"35-49","offsetgroup":"35-49","orientation":"v","showlegend":true,"textposition":"inside","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[35.71001605844176,29.397510470859743,39.450684489128925,33.78533451071629,53.41369574980499,28.189636433238103,57.928578094129655,33.08245363033445,77.59460184093221],"yaxis":"y","type":"bar","texttemplate":"%{y:.2f}%","customdata":["35-49","35-49","35-49","35-49","35-49","35-49","35-49","35-49","35-49"]}],                        {"template":{"data": ...

# %% [markdown]
# ## 3. Outcome variables

# %% [markdown]
# ### 3.1. ANC visits
#
# Variable: anc.less4

# %%
# anc.less4
table_anc_less4 = create_table("senegal.des", "anc.less4", {"0": "4+ times", "1": "< 4 times"})
create_bar_chart(table_anc_less4, "anc.less4", "Proportion of Women Who Visited ANC < 4 Times During The Last Pregnancy").show()
# Out:
# <div>                            <div id="7fb40051-ce26-4071-9e8e-c6ff65be88ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fb40051-ce26-4071-9e8e-c6ff65be88ae")) {                    Plotly.newPlot(                        "7fb40051-ce26-4071-9e8e-c6ff65be88ae",                        [{"alignmentgroup":"True","hovertemplate":"anc.less4=4+ times\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4+ times","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"4+ times","offsetgroup":"4+ times","orientation":"v","showlegend":true,"text":[65.91950099332094,54.13186745686994,43.03193519486174,31.354771370234207,80.16468033298824,77.56500086859378,60.98923947711074,59.84401763430961,60.723832595001305],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[65.91950099332094,54.13186745686994,43.03193519486174,31.354771370234207,80.16468033298824,77.56500086859378,60.98923947711074,59.84401763430961,60.723832595001305],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"anc.less4=\u003c 4 times\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u003c 4 times","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"\u003c 4 times","offsetgroup":"\u003c 4 times","orientation":"v","showlegend":true,"text":[34.08049900667906,45.86813254313005,56.96806480513826,68.6452286297658,19.835319667011756,22.434999131406215,39.01076052288926,40.155982365690384,39.2761674049987],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[34.08049900667906,45.86813254313005,56.96806480513826,68.6452286297658,19.835319667011756,22.434999131406215,39.01076052288926,40.155982365690384,39.2761674049987],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour", ...

# %% [markdown]
# ### 3.2. PNC: lack of check on baby
#
# Variable: baby.nohlthck

# %%
#baby.nohlthck
baby_nohlthck = create_table("senegal.des", "baby.nohlthck", {"0": "Checked", "1": "Not checked"})
create_bar_chart(baby_nohlthck, "baby.nohlthck", "Whether Baby Received PNC").show()
# Out:
# <div>                            <div id="f31ed1f5-750e-4bd8-8ca3-abdebd677f82" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f31ed1f5-750e-4bd8-8ca3-abdebd677f82")) {                    Plotly.newPlot(                        "f31ed1f5-750e-4bd8-8ca3-abdebd677f82",                        [{"alignmentgroup":"True","hovertemplate":"baby.nohlthck=Checked\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Checked","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"Checked","offsetgroup":"Checked","orientation":"v","showlegend":true,"text":[98.59285163432595,88.36767636748229,90.80650142432144,67.89752607732865,100.0,99.88299377243811,98.44440145208337,98.38584027792011,100.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[98.59285163432595,88.36767636748229,90.80650142432144,67.89752607732865,100.0,99.88299377243811,98.44440145208337,98.38584027792011,100.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"baby.nohlthck=Not checked\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not checked","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"Not checked","offsetgroup":"Not checked","orientation":"v","showlegend":true,"text":[1.4071483656740533,11.632323632517704,9.193498575678568,32.10247392267135,0.0,0.11700622756189342,1.5555985479166246,1.6141597220798818,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[1.4071483656740533,11.632323632517704,9.193498575678568,32.10247392267135,0.0,0.11700622756189342,1.5555985479166246,1.6141597220798818,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2 ...

# %% [markdown]
# ### 3.3. PNC: lack of check on woman
#
# Variable:  wom.nohlthck

# %%
#wom.nohlthck
wom_nohlthck = create_table("senegal.des", "wom.nohlthck", {"0": "Checked", "1": "Not checked"})
create_bar_chart(wom_nohlthck, "wom.nohlthck", "Whether Woman Received PNC").show()
# Out:
# <div>                            <div id="5aa5eedf-c878-4167-8d4d-319e381ed0da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5aa5eedf-c878-4167-8d4d-319e381ed0da")) {                    Plotly.newPlot(                        "5aa5eedf-c878-4167-8d4d-319e381ed0da",                        [{"alignmentgroup":"True","hovertemplate":"wom.nohlthck=Checked\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Checked","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"Checked","offsetgroup":"Checked","orientation":"v","showlegend":true,"text":[97.66587157188992,86.92569093041375,87.41298677087552,61.87784706389435,99.42377742736971,100.0,98.87936274795776,97.95427673114919,100.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[97.66587157188992,86.92569093041375,87.41298677087552,61.87784706389435,99.42377742736971,100.0,98.87936274795776,97.95427673114919,100.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"wom.nohlthck=Not checked\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not checked","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"Not checked","offsetgroup":"Not checked","orientation":"v","showlegend":true,"text":[2.3341284281100583,13.07430906958625,12.587013229124485,38.12215293610566,0.5762225726302824,0.0,1.1206372520422387,2.0457232688508076,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[2.3341284281100583,13.07430906958625,12.587013229124485,38.12215293610566,0.5762225726302824,0.0,1.1206372520422387,2.0457232688508076,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222 ...

# %% [markdown]
# ### 3.4. Breastfeeding: the last born no breastfeeding
#
# Variable: no.breastfed

# %%
#no.breastfed
no_breastfed = create_table("senegal.des", "no.breastfed", {"0": "Breastfed", "1": "Not Breastfed"})
create_bar_chart(no_breastfed, "no.breastfed", "Whether The Last Born Baby Was Breastfed").show()
# Out:
# <div>                            <div id="b64f5576-ffde-4788-b777-933aaa9d72db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b64f5576-ffde-4788-b777-933aaa9d72db")) {                    Plotly.newPlot(                        "b64f5576-ffde-4788-b777-933aaa9d72db",                        [{"alignmentgroup":"True","hovertemplate":"no.breastfed=Breastfed\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Breastfed","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"Breastfed","offsetgroup":"Breastfed","orientation":"v","showlegend":true,"text":[98.54790531137645,98.18618647043441,98.40201692358403,97.8319390566394,97.81369855236161,98.00300569402962,98.62773209478048,99.09159972102616,80.63555549687462],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[98.54790531137645,98.18618647043441,98.40201692358403,97.8319390566394,97.81369855236161,98.00300569402962,98.62773209478048,99.09159972102616,80.63555549687462],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"no.breastfed=Not Breastfed\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not Breastfed","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"Not Breastfed","offsetgroup":"Not Breastfed","orientation":"v","showlegend":true,"text":[1.452094688623546,1.8138135295655846,1.5979830764159646,2.1680609433606035,2.1863014476383946,1.9969943059703767,1.3722679052195157,0.9084002789738416,19.36444450312539],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[1.452094688623546,1.8138135295655846,1.5979830764159646,2.1680609433606035,2.1863014476383946,1.9969943059703767,1.3722679052195157,0.9084002789738416,19.36444450312539],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type ...

# %% [markdown]
# ### 3.5. Breastfeeding: anychild was breastfed
#
# Variable: breastfeed.yn

# %%
#breastfeed.yn
breastfeed_yn = create_table("senegal.des", "breastfeed.yn", {"0": "No", "1": "Yes"})
create_bar_chart(breastfeed_yn, "breastfeed.yn", "Whether Any Of The Child Was Breastfed").show()
# Out:
# <div>                            <div id="a2a6a566-ee5b-4afe-bf3e-34b25063482b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2a6a566-ee5b-4afe-bf3e-34b25063482b")) {                    Plotly.newPlot(                        "a2a6a566-ee5b-4afe-bf3e-34b25063482b",                        [{"alignmentgroup":"True","hovertemplate":"breastfeed.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[44.218383592815,44.6282659429761,39.38502145093082,40.623172116991846,51.37571065412466,39.50624692102482,53.190328540174804,39.87122336542894,74.2776061360149],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[44.218383592815,44.6282659429761,39.38502145093082,40.623172116991846,51.37571065412466,39.50624692102482,53.190328540174804,39.87122336542894,74.2776061360149],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"breastfeed.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[55.781616407185005,55.37173405702389,60.614978549069185,59.376827883008154,48.62428934587534,60.493753078975175,46.8096714598252,60.128776634571054,25.722393863985115],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[55.781616407185005,55.37173405702389,60.614978549069185,59.376827883008154,48.62428934587534,60.493753078975175,46.8096714598252,60.128776634571054,25.722393863985115],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0 ...

# %% [markdown]
# ### 3.6. Still birth
#
# Variable: stl.yn

# %%
#stl.yn
stl_yn = create_table("senegal.des", "stl.yn", {"0": "No", "1": "Yes"})
create_bar_chart(stl_yn, "stl.yn", "Whether The Woman Has Experienced Still Birth").show()
# Out:
# <div>                            <div id="24e57b43-60ca-4d68-8d59-ac0f3532cd77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24e57b43-60ca-4d68-8d59-ac0f3532cd77")) {                    Plotly.newPlot(                        "24e57b43-60ca-4d68-8d59-ac0f3532cd77",                        [{"alignmentgroup":"True","hovertemplate":"stl.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[98.81755181401607,98.79256265667755,97.58116144009394,98.47369877358426,100.0,98.72829286230792,99.7928537246573,99.76404444357246,100.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[98.81755181401607,98.79256265667755,97.58116144009394,98.47369877358426,100.0,98.72829286230792,99.7928537246573,99.76404444357246,100.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"stl.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[1.1824481859839202,1.207437343322461,2.418838559906066,1.5263012264157496,0.0,1.2717071376920805,0.2071462753426902,0.23595555642755028,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[1.1824481859839202,1.207437343322461,2.418838559906066,1.5263012264157496,0.0,1.2717071376920805,0.2071462753426902,0.23595555642755028,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444 ...

# %% [markdown]
# ### 3.7. U1 child mortality
#
# Variable: u1mort.yn

# %%
#u1mort.yn
u1mort_yn = create_table("senegal.des", "u1mort.yn", {"0": "No", "1": "Yes"})
create_bar_chart(u1mort_yn, "u1mort.yn", "Whether The Woman Has Experienced U1 Children Death").show()
# Out:
# <div>                            <div id="74a9db35-6967-4d66-a57b-f4b943b6c3cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74a9db35-6967-4d66-a57b-f4b943b6c3cf")) {                    Plotly.newPlot(                        "74a9db35-6967-4d66-a57b-f4b943b6c3cf",                        [{"alignmentgroup":"True","hovertemplate":"u1mort.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[87.67595853145193,81.94095499603964,81.58441047462294,76.53899366097231,90.86414946112825,95.64354145032551,83.31602685782401,87.8365163004441,78.03495903337236],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[87.67595853145193,81.94095499603964,81.58441047462294,76.53899366097231,90.86414946112825,95.64354145032551,83.31602685782401,87.8365163004441,78.03495903337236],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"u1mort.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[12.32404146854807,18.059045003960357,18.415589525377055,23.46100633902769,9.13585053887174,4.356458549674498,16.68397314217599,12.163483699555897,21.96504096662764],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[12.32404146854807,18.059045003960357,18.415589525377055,23.46100633902769,9.13585053887174,4.356458549674498,16.68397314217599,12.163483699555897,21.96504096662764],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1 ...

# %% [markdown]
# ### 3.8. U5 child mortality
#
# Variable: u5mort.yn

# %%
#u5mort.yn
u5mort_yn = create_table("senegal.des", "u5mort.yn", {"0": "No", "1": "Yes"})
create_bar_chart(u5mort_yn, "u5mort.yn", "Whether The Woman Has Experienced U5 Children Death").show()
# Out:
# <div>                            <div id="252c1870-e871-4288-8c18-fe3d25c0561a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("252c1870-e871-4288-8c18-fe3d25c0561a")) {                    Plotly.newPlot(                        "252c1870-e871-4288-8c18-fe3d25c0561a",                        [{"alignmentgroup":"True","hovertemplate":"u5mort.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[82.40882827765688,74.35661863562123,73.85610984136413,66.58321219734881,89.46736815213485,94.40180284581956,74.50587086067587,82.69790053830222,73.4057346342097],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[82.40882827765688,74.35661863562123,73.85610984136413,66.58321219734881,89.46736815213485,94.40180284581956,74.50587086067587,82.69790053830222,73.4057346342097],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"u5mort.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[17.59117172234312,25.64338136437877,26.14389015863587,33.41678780265118,10.532631847865153,5.598197154180435,25.49412913932413,17.302099461697782,26.5942653657903],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[17.59117172234312,25.64338136437877,26.14389015863587,33.41678780265118,10.532631847865153,5.598197154180435,25.49412913932413,17.302099461697782,26.5942653657903],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %% [markdown]
# ### 3.8.1. Infant mortality
#
# Variable: infant.mort.yn

# %%
#infant.mort.yn
infant_mort_yn = create_table("senegal.des", "infant.mort.yn", {"0": "No", "1": "Yes"})
create_bar_chart(infant_mort_yn, "infant.mort.yn", "Whether The Woman Has Experienced Infant  (0-28 Days) Death").show()
# Out:
# <div>                            <div id="0594cdc7-f40c-426c-a44e-918ee59d91ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0594cdc7-f40c-426c-a44e-918ee59d91ba")) {                    Plotly.newPlot(                        "0594cdc7-f40c-426c-a44e-918ee59d91ba",                        [{"alignmentgroup":"True","hovertemplate":"infant.mort.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[91.58933437786945,89.76396016226174,88.63226840708144,87.34001184460828,94.16376348024464,96.94664998534753,90.72964408334866,94.4349239125721,79.30951721999755],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[91.58933437786945,89.76396016226174,88.63226840708144,87.34001184460828,94.16376348024464,96.94664998534753,90.72964408334866,94.4349239125721,79.30951721999755],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"infant.mort.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[8.41066562213055,10.236039837738268,11.367731592918567,12.659988155391714,5.836236519755367,3.0533500146524717,9.270355916651344,5.5650760874279,20.690482780002455],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[8.41066562213055,10.236039837738268,11.367731592918567,12.659988155391714,5.836236519755367,3.0533500146524717,9.270355916651344,5.5650760874279,20.690482780002455],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0 ...

# %% [markdown]
# ### 3.9. Family planning: currently not using modern method
#
# Variable: nofp.mod.now

# %%
#nofp.mod.now
nofp_mod_now = create_table("senegal.des", "nofp.mod.now", {"0": "Yes", "1": "No"})
create_bar_chart(nofp_mod_now, "nofp.mod.now", "Whether The Woman Is Currently Using Modern Contraceptives").show()
# Out:
# <div>                            <div id="e399df1c-c9b9-4ca4-91c6-29a30962d278" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e399df1c-c9b9-4ca4-91c6-29a30962d278")) {                    Plotly.newPlot(                        "e399df1c-c9b9-4ca4-91c6-29a30962d278",                        [{"alignmentgroup":"True","hovertemplate":"nofp.mod.now=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[27.952299797008536,22.526525560463767,20.791627049461333,12.83689443296584,48.35235902075201,37.43641700104299,35.8251903612625,30.042374609270706,15.532137899918602],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[27.952299797008536,22.526525560463767,20.791627049461333,12.83689443296584,48.35235902075201,37.43641700104299,35.8251903612625,30.042374609270706,15.532137899918602],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"nofp.mod.now=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[72.04770020299146,77.47347443953623,79.20837295053867,87.16310556703417,51.64764097924799,62.563582998957,64.1748096387375,69.95762539072929,84.46786210008139],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[72.04770020299146,77.47347443953623,79.20837295053867,87.16310556703417,51.64764097924799,62.563582998957,64.1748096387375,69.95762539072929,84.46786210008139],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...

# %% [markdown]
# ### 3.10. Current family planning: type
#
# Variable: v313

# %%
#v313
v313 = create_table("senegal.des", "v313", {"no method": "Not using any", "folkloric method": "Folkloric", "traditional method": "Traditional", "modern method": "Modern"})
create_bar_chart(v313, "v313", "Type of Contraceptives The Woman Currently Uses").show()
# Out:
# <div>                            <div id="e066b656-3215-4e52-91f8-2113358dba0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e066b656-3215-4e52-91f8-2113358dba0c")) {                    Plotly.newPlot(                        "e066b656-3215-4e52-91f8-2113358dba0c",                        [{"alignmentgroup":"True","hovertemplate":"v313=1\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"1","offsetgroup":"1","orientation":"v","showlegend":true,"text":[70.83363361598077,76.43297084820654,77.32013848930703,86.42775449259605,48.54925197686109,59.90105206769732,63.335764657874584,68.74190947101476,84.46786210008139],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[70.83363361598077,76.43297084820654,77.32013848930703,86.42775449259605,48.54925197686109,59.90105206769732,63.335764657874584,68.74190947101476,84.46786210008139],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"v313=2\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"2","offsetgroup":"2","orientation":"v","showlegend":true,"text":[0.4267296116331197,0.6917390381314111,1.7204558557535097,0.7353510744381133,0.31239013732582155,0.6065954364390218,0.30231985580949206,0.44647679935772533,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[0.4267296116331197,0.6917390381314111,1.7204558557535097,0.7353510744381133,0.31239013732582155,0.6065954364390218,0.30231985580949206,0.44647679935772533,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"v313=3\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"3","marker":{"color":"#6a9f58","pattern":{"shape":""}},"name":"3","offsetgroup":"3","orientation":"v","showlegend":true,"text":[0.7873369753775586,0.3487645531982861,0.1677786054781083,0.0,2.78599886506108,2.0559354948206767,0.5367251250534391,0.7692391203568205,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[0.7873369753775586,0.3487645531982861,0.1677786054781083,0.0,2.78599886506108,2.0559354948206767,0.5367251250534391,0.7692391203568205,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"v313=4\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#e7ca60","pattern":{"shape":""}},"name":"4","offsetgroup":"4","orientation":"v","showlegend":true,"text":[27.952299797008536,22.526525560463767,20.791627049461354,12.83689443296584,48.35235902075201,37.43641700104297,35.82519036126249,30.0423746092707,15.532137899918602],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[27.952299797008536,22.526525560463767,20.791627049461354,12.83689443296584,48.35235902075201,37.43641700104297,35.82519036126249,30.0423746092707,15.532137899918602],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333 ...

# %% [markdown]
# ### 3.11. Current family planning: specific method
#
# Variable: fp.specific

# %%
#fp.specific
v312 = create_table("senegal.des", "v312", {})

dict_v312 = {"1": "Not using", "2": "Pill", "3": "IUD", "4": "Injections", "5": "Diaphragm", "6": "Male condom", "7": "Female sterilization", "8": "Male sterilization", "9": "Periodic abstinence", "10": "Withdrawal", "11": "Other traditional", "12": "Implants", "13": "Prolonged abstinence", "14": "LAM", "15": "Female condom", "16": "Foam or jelly", "17": "Emergency contraception", "18": "Other modern method", "19": "SDM", "20": "Specific method 1", "21": "Specific method 2"}

# Some values are shown explicitly, other are grouped
v312_values_allowed = ["Pill", "IUD", "Injections", "Male Condom", "Implants", "LAM", "Not using"]

# Apply the mapping
v312["fp.specific"] = v312["v312"].apply(
    lambda x: dict_v312.get(x, "Not using") if dict_v312.get(x) in v312_values_allowed else "Other methods"
)

# Group by 'fp.specific' and sum the 'Freq' and 'percentage' columns
v312 = v312.groupby(["Segment", "fp.specific"], as_index=False).agg({
    "Freq": "sum",
    "percentage": "sum"
})

# Sort again, because grouping alter the order desired for the chart
v312 = v312.sort_values(by=["Segment", "percentage"], ascending=[True, False])

create_bar_chart(v312, "fp.specific", "Contraceptives The Woman Currently Uses").show()
# Out:
# <div>                            <div id="829d94f0-9994-4297-ad44-7dc8dcf040c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("829d94f0-9994-4297-ad44-7dc8dcf040c5")) {                    Plotly.newPlot(                        "829d94f0-9994-4297-ad44-7dc8dcf040c5",                        [{"alignmentgroup":"True","hovertemplate":"fp.specific=Not using\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Not using","marker":{"color":"#d1615d","pattern":{"shape":""}},"name":"Not using","offsetgroup":"Not using","orientation":"v","showlegend":true,"text":[70.8336336159808,76.43297084820655,77.32013848930703,86.42775449259604,48.54925197686107,59.901052067697314,63.335764657874584,68.74190947101474,84.46786210008139],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[70.8336336159808,76.43297084820655,77.32013848930703,86.42775449259604,48.54925197686107,59.901052067697314,63.335764657874584,68.74190947101474,84.46786210008139],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"fp.specific=Injections\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Injections","marker":{"color":"#85b6b2","pattern":{"shape":""}},"name":"Injections","offsetgroup":"Injections","orientation":"v","showlegend":true,"text":[11.202368266558182,5.638489126758039,7.988049838570276,4.02251485672598,12.510297946268118,13.703121712527208,8.968830661870836,9.596649249796748,4.134685359551385],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[11.202368266558182,5.638489126758039,7.988049838570276,4.02251485672598,12.510297946268118,13.703121712527208,8.968830661870836,9.596649249796748,4.134685359551385],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"fp.specific=Implants\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Implants","marker":{"color":"#6a9f58","pattern":{"shape":""}},"name":"Implants","offsetgroup":"Implants","orientation":"v","showlegend":true,"text":[8.923443512012657,14.305314427251773,8.547553578643164,6.859117492955619,13.112568502891623,11.462590377446368,16.935728624569137,13.588829190776059,6.6876460140764635],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[8.923443512012657,14.305314427251773,8.547553578643164,6.859117492955619,13.112568502891623,11.462590377446368,16.935728624569137,13.588829190776059,6.6876460140764635],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"fp.specific=Pill\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Pill","marker":{"color":"#e7ca60","pattern":{"shape":""}},"name":"Pill","offsetgroup":"Pill","orientation":"v","showlegend":true,"text":[5.145740166029425,1.110154734545323,1.6945648717441364,0.6466742167058114,11.534327537463613,8.790202374156738,5.29295646118536,3.8718261853780405,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[5.145740166029425,1.110154734545323,1.6945648717441364,0.6466742167058114,11.534327537463613,8.790202374156738,5.29295646118536,3.8718261853780405,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"fp.specific=Other methods\u ...

# %% [markdown]
# ### 3.12. Home birth for the last born
#
# Variable: hb.last, recoded

# %%
#hb.last
hb_last = create_table("senegal.des", "hb.last", {"0": "No", "1": "Yes"})
create_bar_chart(hb_last, "hb.last", "Whether Had Home Birth For The Last Born").show()
# Out:
# <div>                            <div id="27e58dd0-0154-44b0-a28b-418b77f58aeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27e58dd0-0154-44b0-a28b-418b77f58aeb")) {                    Plotly.newPlot(                        "27e58dd0-0154-44b0-a28b-418b77f58aeb",                        [{"alignmentgroup":"True","hovertemplate":"hb.last=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[94.05510761163544,73.25979967307845,69.16672127962474,44.50820777757275,97.42226581136697,96.24134789955403,94.57585039186561,92.56661029677085,97.29064315572707],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[94.05510761163544,73.25979967307845,69.16672127962474,44.50820777757275,97.42226581136697,96.24134789955403,94.57585039186561,92.56661029677085,97.29064315572707],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"hb.last=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[5.94489238836456,26.74020032692155,30.83327872037526,55.491792222427236,2.5777341886330274,3.758652100445964,5.424149608134391,7.433389703229159,2.7093568442729277],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[5.94489238836456,26.74020032692155,30.83327872037526,55.491792222427236,2.5777341886330274,3.758652100445964,5.424149608134391,7.433389703229159,2.7093568442729277],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %% [markdown]
# ### 3.13. Immunization: zero dose
#
# Variable: zerodose.yn

# %%
#zerodose.yn
zerodose_yn = create_table("senegal.des", "zerodose.yn", {"0": "No", "1": "Yes"})
create_bar_chart(zerodose_yn, "zerodose.yn", "Whether The Woman Has A Child Who Received Zero Dose of DPT").show()
# Out:
# <div>                            <div id="10488815-24b9-4c94-b208-b41648da161d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10488815-24b9-4c94-b208-b41648da161d")) {                    Plotly.newPlot(                        "10488815-24b9-4c94-b208-b41648da161d",                        [{"alignmentgroup":"True","hovertemplate":"zerodose.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[90.19749884839213,86.92111453697564,89.30372889849951,76.48224293574039,96.74331994389887,89.6925146375335,91.70606010624415,88.610963941736,100.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[90.19749884839213,86.92111453697564,89.30372889849951,76.48224293574039,96.74331994389887,89.6925146375335,91.70606010624415,88.610963941736,100.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"zerodose.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[9.80250115160786,13.078885463024353,10.696271101500498,23.517757064259616,3.2566800561011378,10.307485362466497,8.293939893755848,11.389036058263992,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[9.80250115160786,13.078885463024353,10.696271101500498,23.517757064259616,3.2566800561011378,10.307485362466497,8.293939893755848,11.389036058263992,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222 ...

# %% [markdown]
# ### 3.14. Last born overweight
#
# Variable: ovrwgt.yn

# %%
#ovrwgt.yn
ovrwgt_yn = create_table("senegal.des", "ovrwgt.yn", {"0": "No", "1": "Yes"})
create_bar_chart(ovrwgt_yn, "ovrwgt.yn", "Whether The Last Born Was Overweight").show()
# Out:
# <div>                            <div id="43309ccf-5bae-4c26-b7a6-f2814859bf01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43309ccf-5bae-4c26-b7a6-f2814859bf01")) {                    Plotly.newPlot(                        "43309ccf-5bae-4c26-b7a6-f2814859bf01",                        [{"alignmentgroup":"True","hovertemplate":"ovrwgt.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[99.12025915423737,99.07278592276751,99.13745174756022,99.43498114572603,98.36527653720259,96.53715314056518,98.29749019476272,97.23377388429469,100.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[99.12025915423737,99.07278592276751,99.13745174756022,99.43498114572603,98.36527653720259,96.53715314056518,98.29749019476272,97.23377388429469,100.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"ovrwgt.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[0.8797408457626298,0.927214077232494,0.8625482524397675,0.5650188542739798,1.6347234627973974,3.462846859434822,1.702509805237282,2.7662261157053027,0.0],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[0.8797408457626298,0.927214077232494,0.8625482524397675,0.5650188542739798,1.6347234627973974,3.462846859434822,1.702509805237282,2.7662261157053027,0.0],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222222 ...

# %% [markdown]
# ### 3.15. Last born stunting
#
# Variable: stunt.cat2.yn

# %%
#stunt.cat2.yn
stunt_cat2_yn = create_table("senegal.des", "stunt.cat2.yn", {"0": "No", "1": "Yes"})
create_bar_chart(stunt_cat2_yn, "stunt.cat2.yn", "Whether The Last Born Was Stunting").show()
# Out:
# <div>                            <div id="c26faf2a-9613-4506-b3e3-3ef4af28da58" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c26faf2a-9613-4506-b3e3-3ef4af28da58")) {                    Plotly.newPlot(                        "c26faf2a-9613-4506-b3e3-3ef4af28da58",                        [{"alignmentgroup":"True","hovertemplate":"stunt.cat2.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[89.53253697397416,82.40073911896413,77.85155995611342,70.60461408467276,91.34916760185891,93.27541692083088,92.38528773995564,84.44121091352424,99.25236809047597],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[89.53253697397416,82.40073911896413,77.85155995611342,70.60461408467276,91.34916760185891,93.27541692083088,92.38528773995564,84.44121091352424,99.25236809047597],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"stunt.cat2.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[10.46746302602584,17.59926088103587,22.14844004388658,29.39538591532724,8.65083239814108,6.724583079169127,7.614712260044366,15.55878908647575,0.7476319095240429],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[10.46746302602584,17.59926088103587,22.14844004388658,29.39538591532724,8.65083239814108,6.724583079169127,7.614712260044366,15.55878908647575,0.7476319095240429],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887" ...

# %% [markdown]
# ### 3.16. Last born underweight
#
# Variable: undwgt.yn

# %%
#undwgt.yn
undwgt_yn = create_table("senegal.des", "undwgt.yn", {"0": "No", "1": "Yes"})
create_bar_chart(undwgt_yn, "undwgt.yn", "Whether The Last Born Was Underweight").show()
# Out:
# <div>                            <div id="7ea75505-2767-4611-88c5-f3331b9791d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ea75505-2767-4611-88c5-f3331b9791d6")) {                    Plotly.newPlot(                        "7ea75505-2767-4611-88c5-f3331b9791d6",                        [{"alignmentgroup":"True","hovertemplate":"undwgt.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[82.94000637973853,75.1379304252168,71.47583702861014,62.61317878746381,88.17345836323186,88.60788561560129,83.47542262369988,81.2539239627245,75.05315864854431],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[82.94000637973853,75.1379304252168,71.47583702861014,62.61317878746381,88.17345836323186,88.60788561560129,83.47542262369988,81.2539239627245,75.05315864854431],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"undwgt.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[17.059993620261455,24.862069574783206,28.52416297138986,37.3868212125362,11.826541636768143,11.392114384398706,16.52457737630012,18.74607603727549,24.94684135145569],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[17.059993620261455,24.862069574783206,28.52416297138986,37.3868212125362,11.826541636768143,11.392114384398706,16.52457737630012,18.74607603727549,24.94684135145569],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1 ...

# %% [markdown]
# ### 3.17. Last born wasting
#
# Variable: waste.cat2.yn

# %%
#waste.cat2.yn
waste_cat2_yn = create_table("senegal.des", "waste.cat2.yn", {"0": "No", "1": "Yes"})
create_bar_chart(waste_cat2_yn, "waste.cat2.yn", "Whether The Last Born Was Wasting").show()
# Out:
# <div>                            <div id="ad66d7aa-d25d-43f5-9c14-9564f82e6529" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad66d7aa-d25d-43f5-9c14-9564f82e6529")) {                    Plotly.newPlot(                        "ad66d7aa-d25d-43f5-9c14-9564f82e6529",                        [{"alignmentgroup":"True","hovertemplate":"waste.cat2.yn=No\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#CCC","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"text":[92.73496565802648,90.419020875498,91.63363789651716,82.3712557358853,91.94725177396947,94.12439345426992,90.0258876320274,94.73351696265946,94.41760315166971],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[92.73496565802648,90.419020875498,91.63363789651716,82.3712557358853,91.94725177396947,94.12439345426992,90.0258876320274,94.73351696265946,94.41760315166971],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}},{"alignmentgroup":"True","hovertemplate":"waste.cat2.yn=Yes\u003cbr\u003eSegment=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#04859B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"text":[7.26503434197351,9.580979124501987,8.366362103482844,17.628744264114708,8.052748226030545,5.875606545730067,9.974112367972596,5.266483037340526,5.582396848330296],"textposition":"auto","x":["R2","R3.1","R3.2","R4","U1","U2.1","U2.2","U3.1","U3.2"],"xaxis":"x","y":[7.26503434197351,9.580979124501987,8.366362103482844,17.628744264114708,8.052748226030545,5.875606545730067,9.974112367972596,5.266483037340526,5.582396848330296],"yaxis":"y","type":"bar","cliponaxis":false,"texttemplate":"%{text:.1f}%","textfont":{"size":16}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...

# %% [markdown]
# ## 4. Outcome variables comparison

# %%
outcomes_list = ["anc.less4", "baby.nohlthck", "wom.nohlthck", "breastfeed.cnt", "breastfeed.yn", "no.breastfed", "stl.yn", "u1mort.yn", 
"u5mort.yn", "infant.mort.yn", "nofp.mod.ever", "nofp.mod.now", "hb.last", "dpt.full.cnt", "dpt.full.yn", "meas.full.cnt", 
"meas.full.yn", "polio.full.cnt", "polio.full.yn", "zerodose.cnt", "zerodose.yn", "mens.noboth", "mens.nopriv", "mens.noprod", 
"ovrwgt.cnt", "ovrwgt.yn", "stunt.cat2.cnt", "stunt.cat2.yn", "undwgt.cnt", "undwgt.yn", "waste.cat2.cnt", "waste.cat2.yn"]

outcomes_df = pd.read_excel("Senegal/additional_files/Outcome variables.xlsx", sheet_name=0, usecols="A:D")
outcomes_df.rename(columns={"outcomes": "variable"}, inplace=True)
display(outcomes_df)
# Out:
#             category        variable                          short_name  \
# 0            ANC/PNC       anc.less4                      ANC Visits < 4
# 1            ANC/PNC   baby.nohlthck                     No Baby Checkup
# 2            ANC/PNC    wom.nohlthck                    No Woman Checkup
# 3      Breastfeeding  breastfeed.cnt               Breastfed Child Count
# 4      Breastfeeding   breastfeed.yn                       Breastfed Y/N
# 5      Breastfeeding    no.breastfed                  Breastfed Last Y/N
# 6    Child Mortality          stl.yn                     Still birth Y/N
# 7    Child Mortality       u1mort.yn                    U1 Mortality Y/N
# 8    Child Mortality       u5mort.yn                    U5 Mortality Y/N
# 9    Child Mortality  infant.mort.yn                Infant Mortality Y/N
# 10   Family Planning   nofp.mod.ever                    No Modern FP Use
# 11   Family Planning    nofp.mod.now                No Modern FP Use Now
# 12       Home Births         hb.last  Home Birth for the last born child
# 13      Immunization    dpt.full.cnt                      DPT Immz Count
# 14      Immunization     dpt.full.yn                        DPT Immz Y/N
# 15      Immunization   meas.full.cnt                      MMR Immz Count
# 16      Immunization    meas.full.yn                        MMR Immz Y/N
# 17      Immunization  polio.full.cnt                    Polio Immz Count
# 18      Immunization   polio.full.yn                      Polio Immz Y/N
# 19      Immunization    zerodose.cnt                Zero Dose Immz Count
# 20      Immunization     zerodose.yn                  Zero Dose Immz Y/N
# 21  Menstrual Health     mens.noboth                                 NaN
# 22  Menstrual Health     mens.nopriv                                 NaN
# 23  Menstrual Health     mens.noprod                                 NaN
# 24    Malnourishment      ovrwgt.cnt              Overweight Child Count
# 25    Malnourishment       ovrwgt.yn                Overweight Child Y/N
# 26    Malnourishment  stunt.cat2.cnt                 Stunted Child Count
# 27    Malnourishment   stunt.cat2.yn                   Stunted Child Y/N
# 28    Malnourishment      undwgt.cnt             Underweight Child Count
# 29    Malnourishment       undwgt.yn               Underweight Child Y/N
# 30    Malnourishment  waste.cat2.cnt                  Wasted Child Count
# 31    Malnourishment   waste.cat2.yn                    Wasted Child Y/N
#
#                                           description
# 0                            If <4 ANC visits then =1
# 1                     If no baby health check then =1
# 2                     If no woman health check then=1
# 3                         Count of children breastfed
# 4                      If any child breastfed then =1
# 5                 If last child not breastfed then =1
# 6                         If any still births then =1
# 7                         If any u1 mortality then =1
# 8                         If any u5 mortality then =1
# 9                    If any infant mortality then = 1
# 10  If no modern family planning method use ever t...
# 11  If not currently using modern family planning ...
# 12             If latest birth was home birth then =1
# 13                         Count of children immz DPT
# 14                      If any child DPT immz then =1
# 15                         Count of children immz MMR
# 16                      If any child MMR immz then =1
# 17                       Count of children immz polio
# 18                    If any child Polio immz then =1
# 19                 Count of children w/o any DPT immz
# 20              If any child without DPT immz then =1
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                       Count of children overweight
# 25                    If any child overweight then =1
# 26                          Count of stunted children
# 27                       If any child stunted then =1
# 28                      Count of children underweight
# 29                   If any child underweight then =1
# 30                           Count of wasted children
# 31                        If any child wasted then =1

# %% [markdown]
# ### 4.1. Rural Segments

# %%
# remove some inconvenient variables, because are counts or not relevant
variables_to_exclude = ["breastfeed.cnt", "breastfeed.yn", "dpt.full.cnt", "meas.full.cnt", "polio.full.cnt", "zerodose.cnt", "ovrwgt.cnt", "ovrwgt.yn", "stunt.cat2.cnt", "undwgt.cnt", "waste.cat2.cnt", "breastfeed.cnt", "breastfeed.yn", "dpt.full.cnt", "meas.full.cnt", "polio.full.cnt", "zerodose.cnt", "ovrwgt.cnt", "ovrwgt.yn", "stunt.cat2.cnt", "undwgt.cnt", "waste.cat2.cnt"]

# %%
# Group by 'Segment' and calculate the mean for each column in outcomes
rural_cluster_means = (
    df_rural.groupby("Segment")[outcomes_list]
    .mean()
    .reset_index()
)

# Calculate the overall mean for each column in outcomes
rural_overall_means = df_rural[outcomes_list].mean()

# Convert the result to a DataFrame if needed
rural_overall_means_df = rural_overall_means.reset_index()
rural_overall_means_df.columns = ["variable", "Mean"]  # Rename columns for clarity

# Transposing
rural_final_means = rural_cluster_means.melt(
    id_vars=["Segment"],  # Keep 'Segment' as is
    var_name="variable",  # New column for original column names ()
    value_name="cluster_mean"  # New column for corresponding values
)

# Merge the DataFrames on the "variable" column
rural_final_means = rural_final_means.merge(rural_overall_means_df, on="variable", how="left")

# Add columns with some calculations
rural_final_means["difference"] = rural_final_means["cluster_mean"] - rural_final_means["Mean"]
rural_final_means["percent_difference"] = rural_final_means["difference"] / rural_final_means["Mean"]

# Merge with descriptive data from Excel
rural_final_means = rural_final_means.merge(outcomes_df, on="variable", how="left")

# Exclude rows where "variable" column contains values in the list
rural_final_means = rural_final_means[~rural_final_means["variable"].isin(variables_to_exclude)]

# Inspect the resulting DataFrame
display(rural_final_means)
# Out:
#     Segment       variable  cluster_mean      Mean  difference  \
# 0        R2      anc.less4      0.330696  0.523597   -0.192900
# 1      R3.1      anc.less4      0.467262  0.523597   -0.056335
# 2      R3.2      anc.less4      0.582539  0.523597    0.058942
# 3        R4      anc.less4      0.695392  0.523597    0.171796
# 4        R2  baby.nohlthck      0.015044  0.137317   -0.122273
# ..      ...            ...           ...       ...         ...
# 119      R4      undwgt.yn      0.363481  0.273764    0.089717
# 124      R2  waste.cat2.yn      0.079114  0.106017   -0.026903
# 125    R3.1  waste.cat2.yn      0.098214  0.106017   -0.007802
# 126    R3.2  waste.cat2.yn      0.088041  0.106017   -0.017975
# 127      R4  waste.cat2.yn      0.160410  0.106017    0.054393
#
#      percent_difference        category             short_name  \
# 0             -0.368414         ANC/PNC         ANC Visits < 4
# 1             -0.107592         ANC/PNC         ANC Visits < 4
# 2              0.112571         ANC/PNC         ANC Visits < 4
# 3              0.328108         ANC/PNC         ANC Visits < 4
# 4             -0.890446         ANC/PNC        No Baby Checkup
# ..                  ...             ...                    ...
# 119            0.327716  Malnourishment  Underweight Child Y/N
# 124           -0.253759  Malnourishment       Wasted Child Y/N
# 125           -0.073595  Malnourishment       Wasted Child Y/N
# 126           -0.169553  Malnourishment       Wasted Child Y/N
# 127            0.513061  Malnourishment       Wasted Child Y/N
#
#                           description
# 0            If <4 ANC visits then =1
# 1            If <4 ANC visits then =1
# 2            If <4 ANC visits then =1
# 3            If <4 ANC visits then =1
# 4     If no baby health check then =1
# ..                                ...
# 119  If any child underweight then =1
# 124       If any child wasted then =1
# 125       If any child wasted then =1
# 126       If any child wasted then =1
# 127       If any child wasted then =1
#
# [84 rows x 9 columns]

# %%
# Create the figures for all the outcomes and store in a dictionary
# -----------------------------------------------------------------

# Get unique categories
categories = rural_final_means["category"].unique()

# Create a dictionary to store the figures for each category
figures = {}

for category in categories:
    # Filter the DataFrame for the current category
    filtered_df = rural_final_means[rural_final_means["category"] == category]
    
    # Get the unique variables for this category
    variables = filtered_df["variable"].unique()
    
    # Create the line chart using "short_name" for X-axis labels
    fig = px.line(
        filtered_df,
        x="short_name",  # Updated to use short_name for X-axis
        y="percent_difference",
        color="Segment",
        markers=True,
        title=f"Line Chart for {category}",
        labels={"percent_difference": "Percent Difference", "short_name": "Variable"},  # Updated label
        color_discrete_map=colors  # Use custom colors
    )
    
    # Customize layout
    fig.update_layout(
        title_x=0.5,
        xaxis_title="Variable",
        yaxis_title="Percent difference from the sample mean",  # Updated Y-axis title
        legend_title="Segment",
        yaxis_range=[-1, 1]
    )
    
    # Save the figure in the dictionary
    figures[category] = fig
    
    # Example of usage: Show the figure for a specific category
    # figures["Child Mortality"].show()

# %%
# Store only figure objects in the list
current_figures = [figures["ANC/PNC"], figures["Breastfeeding"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["ANC/PNC", "Breastfeeding"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1, 1.5]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="fba5a332-a289-4507-971c-20abf9c59bcc" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fba5a332-a289-4507-971c-20abf9c59bcc")) {                    Plotly.newPlot(                        "fba5a332-a289-4507-971c-20abf9c59bcc",                        [{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[-0.3684140446309324,-0.8904464180080528,-0.8701233202095469],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[-0.10759163768027505,-0.059626128591645775,-0.16076350322925675],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[0.11257142839234136,-0.29123450374154886,-0.1920606973477987],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R4","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[0.3281075734094556,1.3416779910537344,1.2625413320736891],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[-0.17312592470820315],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[0.12327999381570823],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[-0.06278167906927994],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R4","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[0.18904303887239046],"yaxis": ...

# %%
# Store only figure objects in the list
current_figures = [figures["Child Mortality"], figures["Family Planning"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["Child Mortality", "Family Planning"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1, 1.5]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="0b931a72-d95f-44ae-b2de-4cd0e212e6f0" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0b931a72-d95f-44ae-b2de-4cd0e212e6f0")) {                    Plotly.newPlot(                        "0b931a72-d95f-44ae-b2de-4cd0e212e6f0",                        [{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-0.3413668852265343,-0.3186171867294839,-0.32324947690688854,-0.22256795406786675],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-0.1781831582826607,0.050816393268082724,0.03076494702638194,0.027275135553172285],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[0.4553760809267419,0.0014329261679368226,0.013534223273205491,0.05792644240798838],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R4","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-0.06198077691547306,0.3458812299291346,0.34901236074548025,0.17961971827428466],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":false,"x":["No Modern FP Use","No Modern FP Use Now"],"xaxis":"x2","y":[0.13498908610488836,-0.08730127698515039],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":false,"x":["No Modern FP Use","No Modern FP Use Now"],"xaxis":"x2","y":[0.06612828928427478,0.0032470221962778672],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":false,"x":["No Modern FP Use","No Modern FP Use Now"],"xaxis":"x2","y":[0.08528026548416091,-0.010142646266641577],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Se ...

# %%
# Store only figure objects in the list
current_figures = [figures["Home Births"], figures["Immunization"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["Home Births", "Immunization"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1, 1.5]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="200e08a9-727a-4d61-84b7-7afd9b543fd6" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("200e08a9-727a-4d61-84b7-7afd9b543fd6")) {                    Plotly.newPlot(                        "200e08a9-727a-4d61-84b7-7afd9b543fd6",                        [{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[-0.7859495585897853],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[-0.07397701894676166],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[0.049585267880431994],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R4","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[0.8323959715603104],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio Immz Y\u002fN","Zero Dose Immz Y\u002fN"],"xaxis":"x2","y":[-0.27608896930460053,-0.06108489894131079,-0.1769213449002418,-0.31184631803628604],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio Immz Y\u002fN","Zero Dose Immz Y\u002fN"],"xaxis":"x2","y":[-0.019662200318291537,0.00032153829011663965,0.032962357227385754,-0.05249169435215965],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio Immz Y\u002fN","Zero Dose Immz Y\u002fN"],"xaxis":"x2","y":[-0.11018536103232036,-0.025235968673009826,-0.12679797468515117,-0.23309105325756582],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# Store only one figure (leave space for the second)
current_figures = [figures["Malnourishment"], None]  # Second column left empty

# Create a subplot layout with 2 columns
subplot_fig = make_subplots(
    rows=1, cols=2,  # Keep 2 columns
    subplot_titles=["Malnourishment", ""]  # Empty title for second column
)

# Add first figure's traces
fig = current_figures[0]  # Only the first figure
if isinstance(fig, go.Figure):  # Ensure it's a valid Plotly figure
    for trace in fig.data:
        trace.showlegend = True  # Keep the legend
        subplot_fig.add_trace(trace, row=1, col=1)
    subplot_fig.update_layout({"height": 480, "yaxis1_range": [-1, 1.5]})

# Move the legend closer to the first column
subplot_fig.update_layout(
    legend=dict(
        x=0.5,          # Move legend to the left
        y=1,          # Keep legend at the top
        xanchor="left"  # Align legend properly
    )
)

# Set Y-axis title only for the first subplot
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="ef17d485-c6d6-4731-affb-0fb10ee64488" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef17d485-c6d6-4731-affb-0fb10ee64488")) {                    Plotly.newPlot(                        "ef17d485-c6d6-4731-affb-0fb10ee64488",                        [{"hovertemplate":"Segment=R2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R2","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R2","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.4567071026722926,-0.32955344585091423,-0.25375874592746883],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.1\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.1","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.14478615520282195,-0.09224123677248679,-0.07359478601567213],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R3.2\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R3.2","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[0.11128773674628403,0.06930178527757393,-0.16955338651708352],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=R4\u003cbr\u003eVariable=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"R4","line":{"color":"#F26185","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"R4","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[0.4461509290860825,0.3277161547212742,0.5130614478478133],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d ...

# %% [markdown]
# ### 4.2. Urban Segments

# %%
# Group by 'Segment' and calculate the mean for each column in outcomes
urban_cluster_means = (
    df_urban.groupby("Segment")[outcomes_list]
    .mean()
    .reset_index()
)

# Calculate the overall mean for each column in outcomes
urban_overall_means = df_urban[outcomes_list].mean()

# Convert the result to a DataFrame if needed
urban_overall_means_df = urban_overall_means.reset_index()
urban_overall_means_df.columns = ["variable", "Mean"]  # Rename columns for clarity

# Transposing
urban_final_means = urban_cluster_means.melt(
    id_vars=["Segment"],  # Keep 'Segment' as is
    var_name="variable",  # New column for original column names ()
    value_name="cluster_mean"  # New column for corresponding values
)

# Merge the DataFrames on the "variable" column
urban_final_means = urban_final_means.merge(urban_overall_means_df, on="variable", how="left")

# Add columns with some calculations
urban_final_means["difference"] = urban_final_means["cluster_mean"] - urban_final_means["Mean"]
urban_final_means["percent_difference"] = urban_final_means["difference"] / urban_final_means["Mean"]

# Merge with descriptive data from Excel
urban_final_means = urban_final_means.merge(outcomes_df, on="variable", how="left")

# Exclude rows where "variable" column contains values in the list
urban_final_means = urban_final_means[~urban_final_means["variable"].isin(variables_to_exclude)]

# Inspect the resulting DataFrame
display(urban_final_means)
# Out:
#     Segment       variable  cluster_mean      Mean  difference  \
# 0        U1      anc.less4      0.183673  0.292669   -0.108995
# 1      U2.1      anc.less4      0.198795  0.292669   -0.093873
# 2      U2.2      anc.less4      0.390977  0.292669    0.098309
# 3      U3.1      anc.less4      0.388889  0.292669    0.096220
# 4      U3.2      anc.less4      0.400000  0.292669    0.107331
# ..      ...            ...           ...       ...         ...
# 155      U1  waste.cat2.yn      0.078717  0.083871   -0.005154
# 156    U2.1  waste.cat2.yn      0.086345  0.083871    0.002474
# 157    U2.2  waste.cat2.yn      0.095238  0.083871    0.011367
# 158    U3.1  waste.cat2.yn      0.073333  0.083871   -0.010538
# 159    U3.2  waste.cat2.yn      0.133333  0.083871    0.049462
#
#      percent_difference        category        short_name  \
# 0             -0.372418         ANC/PNC    ANC Visits < 4
# 1             -0.320750         ANC/PNC    ANC Visits < 4
# 2              0.335905         ANC/PNC    ANC Visits < 4
# 3              0.328769         ANC/PNC    ANC Visits < 4
# 4              0.366733         ANC/PNC    ANC Visits < 4
# ..                  ...             ...               ...
# 155           -0.061449  Malnourishment  Wasted Child Y/N
# 156            0.029503  Malnourishment  Wasted Child Y/N
# 157            0.135531  Malnourishment  Wasted Child Y/N
# 158           -0.125641  Malnourishment  Wasted Child Y/N
# 159            0.589744  Malnourishment  Wasted Child Y/N
#
#                      description
# 0       If <4 ANC visits then =1
# 1       If <4 ANC visits then =1
# 2       If <4 ANC visits then =1
# 3       If <4 ANC visits then =1
# 4       If <4 ANC visits then =1
# ..                           ...
# 155  If any child wasted then =1
# 156  If any child wasted then =1
# 157  If any child wasted then =1
# 158  If any child wasted then =1
# 159  If any child wasted then =1
#
# [105 rows x 9 columns]

# %%
# Create the figures for all the outcomes and store in a dictionary
# -----------------------------------------------------------------

# Get unique categories
categories = urban_final_means["category"].unique()

# Create a dictionary to store the figures for each category
figures = {}

for category in categories:
    # Filter the DataFrame for the current category
    filtered_df = urban_final_means[urban_final_means["category"] == category]
    
    # Get the unique variables for this category
    variables = filtered_df["variable"].unique()
    
    # Create the line chart
    fig = px.line(
        filtered_df,
        x="short_name",
        y="percent_difference",
        color="Segment",
        markers=True,
        title=f"Line Chart for {category}",
        labels={"percent_difference": "Percent Difference", "variable": "Variable"},
        color_discrete_map=colors  # Use custom colors
    )
    
    # Customize layout
    fig.update_layout(
        title_x=0.5,
        xaxis_title="Variable",
        yaxis_title="Percent Difference",
        legend_title="Segment",
        yaxis_range=[-1, 1]
    )
    
    # Save the figure in the dictionary
    figures[category] = fig
    
    # Example of usage: Show the figure for a specific category
    # figures["Child Mortality"].show()

# %%
# Store only figure objects in the list
current_figures = [figures["ANC/PNC"], figures["Breastfeeding"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["ANC/PNC", "Breastfeeding"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1.2, 3]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="1e5f33c7-493e-4d14-a0a9-336d73154f31" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e5f33c7-493e-4d14-a0a9-336d73154f31")) {                    Plotly.newPlot(                        "1e5f33c7-493e-4d14-a0a9-336d73154f31",                        [{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[-0.37241830599975456,-1.0,-0.808816914080072],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[-0.32074993360214404,-0.8445216755075909,-1.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[0.3359048924917504,0.16491548652352667,0.14998067259373785],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.1","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[0.328768648407927,1.5872564935064934,1.6270604395604396],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.2","orientation":"v","showlegend":true,"x":["ANC Visits \u003c 4","No Baby Checkup","No Woman Checkup"],"xaxis":"x","y":[0.3667334669338678,-1.0,-1.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[-0.3786443148688047],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[0.06990461847389558],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":false,"x":["Breastfed Last Y\u002fN"],"xaxis":"x2","y":[ ...

# %%
# Store only figure objects in the list
current_figures = [figures["Child Mortality"], figures["Family Planning"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["Child Mortality", "Family Planning"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1.2, 3]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="1883425b-63bd-404a-b8ce-beac283320c9" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1883425b-63bd-404a-b8ce-beac283320c9")) {                    Plotly.newPlot(                        "1883425b-63bd-404a-b8ce-beac283320c9",                        [{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-1.0,-0.24958200832704974,-0.299535205981697,-0.18933718364344682],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[1.0120257452574524,-0.5515802762944044,-0.6021979145369045,-0.5307616245417712],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-0.2911445279866333,0.7175582627118645,0.8031094527363183,0.6231660798122065],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.1","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-0.05089485458612981,-0.03898305084745757,-0.009552238805970158,-0.08309859154929577],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.2","orientation":"v","showlegend":true,"x":["Still birth Y\u002fN","U1 Mortality Y\u002fN","U5 Mortality Y\u002fN","Infant Mortality Y\u002fN"],"xaxis":"x","y":[-1.0,0.8819251201619024,0.7337046112719982,1.405928105949127],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":false,"x":["No Modern FP Use","No Modern FP Use Now"],"xaxis":"x2","y":[0.0690059116789713,-0.15370365325414773],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":false,"x":["No Modern FP Use","No Modern FP Use Now"],"xaxis":"x2","y":[0.017340343430445694, ...

# %%
# Store only figure objects in the list
current_figures = [figures["Home Births"], figures["Immunization"]]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["Home Births", "Immunization"]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1.2, 3]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=2)

# Show the combined figure
subplot_fig.show()
# Out:
# <div>                            <div id="1abc1853-8487-4432-97e5-0080c7f778b8" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1abc1853-8487-4432-97e5-0080c7f778b8")) {                    Plotly.newPlot(                        "1abc1853-8487-4432-97e5-0080c7f778b8",                        [{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[-0.5857628765792032],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[-0.5363746653279786],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[0.42439431913116116],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.1","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[0.657638888888889],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.2","orientation":"v","showlegend":true,"x":["Home Birth for the last born child"],"xaxis":"x","y":[0.18402777777777776],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio Immz Y\u002fN","Zero Dose Immz Y\u002fN"],"xaxis":"x2","y":[-0.5295755713462647,-0.20304908694923782,-0.36577780718586644,-0.4053686471009305],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio Immz Y\u002fN","Zero Dose Immz Y\u002fN"],"xaxis":"x2","y":[0.07622730958767393,0.0276976655602112,0.09866964688688785,0.06970471983259718],"yaxis":"y2","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":false,"x":["DPT Immz Y\u002fN","MMR Immz Y\u002fN","Polio  ...

# %%
# Store only figure objects in the list
current_figures = [figures["Malnourishment"], None]  # Add actual Plotly figures here

# Create a subplot layout
subplot_fig = make_subplots(
    rows=1, cols=len(current_figures),
    subplot_titles=["Malnourishment", ""]
)

# Add each figure's traces to a subplot
for idx, fig in enumerate(current_figures):
    if isinstance(fig, go.Figure):  # Ensure the object is a Plotly figure
        for trace in fig.data:
            # Only show the legend for the first subplot
            trace.showlegend = idx == 0
            subplot_fig.add_trace(trace, row=1, col=idx+1)
            subplot_fig.update_layout({"height":480, f"yaxis{idx + 1}_range": [-1.2, 3]})
    else:
        print(f"Skipping non-figure object at index {idx}: {type(fig)}")

# Move the legend closer to the first column
subplot_fig.update_layout(
    legend=dict(
        x=0.5,          # Move legend to the left
        y=1,          # Keep legend at the top
        xanchor="left"  # Align legend properly
    )
)

# Set Y-axis title for the first column (applies to all if shared axis)
subplot_fig.update_yaxes(title_text="Percent difference from the sample mean", row=1, col=1)

# Show the combined figure
subplot_fig.show()
# Out:
# Skipping non-figure object at index 1: <class 'NoneType'>
# <div>                            <div id="a9e907cb-2ffe-4823-8c9e-f698e5f2441d" class="plotly-graph-div" style="height:480px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9e907cb-2ffe-4823-8c9e-f698e5f2441d")) {                    Plotly.newPlot(                        "a9e907cb-2ffe-4823-8c9e-f698e5f2441d",                        [{"hovertemplate":"Segment=U1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U1","line":{"color":"#21D6D6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U1","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.22609591313000815,-0.19536673867902773,-0.061448755326306344],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.1","line":{"color":"#14ABF7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.1","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.26195801168746846,-0.12560313195226955,0.029502625888168044],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U2.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U2.2","line":{"color":"#76B5E5","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U2.2","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.1555985772815272,-0.016245650096464267,0.13553113553113538],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.1\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.1","line":{"color":"#8B7FEA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.1","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[0.6108449767132401,0.2947641886490807,-0.1256410256410257],"yaxis":"y","type":"scatter"},{"hovertemplate":"Segment=U3.2\u003cbr\u003eshort_name=%{x}\u003cbr\u003ePercent Difference=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"U3.2","line":{"color":"#B5A4EA","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"U3.2","orientation":"v","showlegend":true,"x":["Stunted Child Y\u002fN","Underweight Child Y\u002fN","Wasted Child Y\u002fN"],"xaxis":"x","y":[-0.3193612774451098,0.22661870503597126,0.5897435897435896],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.111 ...
